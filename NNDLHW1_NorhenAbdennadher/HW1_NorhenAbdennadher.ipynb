# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.model_selection import KFold

# %%
# !wget -P regression_dataset https://gitlab.dei.unipd.it/gadaleta/nnld-2020-21-lab-resources/-/raw/master/homework_1_regression_dataset/train_data.csv
# !wget -P regression_dataset https://gitlab.dei.unipd.it/gadaleta/nnld-2020-21-lab-resources/-/raw/master/homework_1_regression_dataset/test_data.csv
# Out:
# --2021-08-21 12:29:49--  https://gitlab.dei.unipd.it/gadaleta/nnld-2020-21-lab-resources/-/raw/master/homework_1_regression_dataset/train_data.csv
# Resolving gitlab.dei.unipd.it (gitlab.dei.unipd.it)... 147.162.2.85
# Connecting to gitlab.dei.unipd.it (gitlab.dei.unipd.it)|147.162.2.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3776 (3.7K) [text/plain]
# Saving to: ‘regression_dataset/train_data.csv’
#
# train_data.csv      100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2021-08-21 12:29:50 (86.9 MB/s) - ‘regression_dataset/train_data.csv’ saved [3776/3776]
#
# --2021-08-21 12:29:50--  https://gitlab.dei.unipd.it/gadaleta/nnld-2020-21-lab-resources/-/raw/master/homework_1_regression_dataset/test_data.csv
# Resolving gitlab.dei.unipd.it (gitlab.dei.unipd.it)... 147.162.2.85
# Connecting to gitlab.dei.unipd.it (gitlab.dei.unipd.it)|147.162.2.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3788 (3.7K) [text/plain]
# Saving to: ‘regression_dataset/test_data.csv’
#
# test_data.csv       100%[===================>]   3.70K  --.-KB/s    in 0s
#
# 2021-08-21 12:29:51 (78.7 MB/s) - ‘regression_dataset/test_data.csv’ saved [3788/3788]

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
#Initializing a seed for the random varibles
torch.manual_seed(968)

# %% [markdown]
# **Network definition**

# %%
class Net(nn.Module):
    
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        print('Network initialized')
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()
   
    def reset_weights(self):
      torch.nn.init.xavier_uniform_(self.fc1.weight)
      torch.nn.init.xavier_uniform_(self.fc2.weight)
        
    def forward(self, x, additional_out=False):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# **Dataset Visualization**

# %%
train_df = pd.read_csv('/content/regression_dataset/train_data.csv')
print(train_df)
# Out:
#        input     label
# 0  -4.787870 -1.216804
# 1  -3.509057  3.277581
# 2  -3.855373  2.621375
# 3  -4.083518  1.046088
# 4  -4.230588  1.228874
# ..       ...       ...
# 95  4.745864  5.839698
# 96  4.454523  3.584919
# 97  4.547246  4.586484
# 98  4.649648  5.185536
# 99  4.781836  6.616912
#
# [100 rows x 2 columns]

# %% [markdown]
# **Analyze the basic statistical values of our dataset**

# %%
train_df.describe()
# Out:
#             input       label
# count  100.000000  100.000000
# mean     0.535661    2.826761
# std      3.511726    1.962990
# min     -4.915863   -3.742970
# 25%     -3.255942    1.677844
# 50%      0.037716    2.663394
# 75%      4.143882    3.727911
# max      4.977516    7.199304

# %%
sample_index = 0
input = train_df.iloc[sample_index]['input']
label = train_df.iloc[sample_index]['label']

print(f"SAMPLE AT INDEX {sample_index}")
print(f"INPUT: {input}")
print(f"LABEL: {label}")
# Out:
# SAMPLE AT INDEX 0
# INPUT: -4.787870188090535
# LABEL: -1.216803599957529

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(train_df.input, train_df.label, label='Training points')
plt.xlabel('input')
plt.ylabel('label')
plt.legend()
plt.show()

# %%
# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Training device: {device}")
# Out:
# Training device: cuda

# %% [markdown]
# **Training Regression + Cross validation**

# %%
#random permutation of the training set
torch_tensor_x = torch.tensor(train_df['input'].values)
torch_tensor_y = torch.tensor(train_df['label'].values)
permutation = np.random.permutation(100)
x_train = torch_tensor_x[permutation]
y_train = torch_tensor_y[permutation]

#Defining parameters
batch_size=16
n_split=3
num_epochs = 2000
train_loss_log = []
val_loss_log = []
train_loss_fold=[]
val_loss_fold=[]
list_out=[]
#Initializing the network
Ni = 1
Nh1 = 128
Nh2 = 256
No = 1
net = Net(Ni, Nh1, Nh2, No)
net.to(device)

# Define the loss function
loss_fn = nn.MSELoss()

# Define the optimizer
optimizer = optim.Adam(net.parameters(), lr=1e-2)
kf = KFold(n_splits=n_split)
i=0
for train_index, val_index in kf.split(x_train, y_train):  
    i+=1
    net.reset_weights()
    print('Fold number %d' %(i))
    x_train_fold = x_train[train_index] 
    y_train_fold = y_train[train_index] 
    x_val_fold = x_train[val_index] 
    y_val_fold = y_train[val_index] 
    #print(x_train_fold)
    #print(x_val_fold)
    #so now x_train_fold,y_train_fold contain the training set as a torch tensor and x_val_fold, y_val_fold contain the validation set as tensor.

    #DataLoader
    train = torch.utils.data.TensorDataset(x_train_fold, y_train_fold)
    val = torch.utils.data.TensorDataset(x_val_fold, y_val_fold)
    train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = False,num_workers=0)
    val_loader = torch.utils.data.DataLoader(val, batch_size = len(val), shuffle =False ,num_workers=0)
    #start the training
    for epoch_num in range(num_epochs):
        print('#################')
        print(f'# EPOCH {epoch_num} ')
        print(f'#FOLD {i}')
        print('#################')

        ### TRAIN
        train_loss= []
        net.train() # Training mode (e.g. enable dropout)
        for batch_index, (xx_batch, y_batch) in enumerate(train_loader):
          # Move data to device
          x_batch = xx_batch.to(device)
          label_batch = y_batch.to(device)
          x_batch=torch.unsqueeze(x_batch, 1)
          label_batch= torch.unsqueeze(label_batch, 1)

          # Forward pass
          x_batch = x_batch.view(x_batch.size(0), -1)
          out = net(x_batch.float())

          # Compute loss
          
          loss = loss_fn(out, label_batch.float())
          loss=loss

          # Backpropagation
          net.zero_grad()
          loss.backward()

          # Update the weights
          optimizer.step()

          # Save train loss for this batch
          loss_batch = loss.detach().cpu().numpy()
          train_loss.append(loss_batch)

        # Save average train loss
        train_loss = np.mean(train_loss)
        print(f"AVERAGE TRAIN LOSS: {train_loss}")
        train_loss_log.append(train_loss)

        ### VALIDATION
        val_loss= []
        net.eval() # Evaluation mode (e.g. disable dropout)
        with torch.no_grad(): # Disable gradient tracking
          for batch_index, (xx_batch, y_batch) in enumerate(val_loader):
            # Move data to device
            x_batch = xx_batch.to(device)
            label_batch = y_batch.to(device)
            x_batch=torch.unsqueeze(x_batch, 1)
            label_batch= torch.unsqueeze(label_batch, 1)

            # Forward pass
            x_batch = x_batch.view(x_batch.size(0), -1)
            out = net(x_batch.float())

            # Compute loss
            loss = loss_fn(out, label_batch.float())

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)

          # Save average validation loss
          val_loss = np.mean(val_loss)
          print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
          val_loss_log.append(val_loss)
    ### Save network parameters after each fold
    net_state_dict = net.state_dict()
    # Save the state dict to a file
    torch.save(net_state_dict, 'net_parameters.torch %d' %i)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# AVERAGE TRAIN LOSS: 0.2032877653837204
# AVERAGE VAL LOSS: 0.36263224482536316
# #################
# # EPOCH 1167
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20375072956085205
# AVERAGE VAL LOSS: 0.2956448197364807
# #################
# # EPOCH 1168
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2060503214597702
# AVERAGE VAL LOSS: 0.4073171019554138
# #################
# # EPOCH 1169
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18216849863529205
# AVERAGE VAL LOSS: 0.3083352744579315
# #################
# # EPOCH 1170
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1821000725030899
# AVERAGE VAL LOSS: 0.34243422746658325
# #################
# # EPOCH 1171
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18706241250038147
# AVERAGE VAL LOSS: 0.3540166914463043
# #################
# # EPOCH 1172
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18523916602134705
# AVERAGE VAL LOSS: 0.33581802248954773
# #################
# # EPOCH 1173
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19494375586509705
# AVERAGE VAL LOSS: 0.32375234365463257
# #################
# # EPOCH 1174
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18715375661849976
# AVERAGE VAL LOSS: 0.3840028643608093
# #################
# # EPOCH 1175
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19164489209651947
# AVERAGE VAL LOSS: 0.2997448444366455
# #################
# # EPOCH 1176
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18914735317230225
# AVERAGE VAL LOSS: 0.3790298402309418
# #################
# # EPOCH 1177
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.177248015999794
# AVERAGE VAL LOSS: 0.3210466802120209
# #################
# # EPOCH 1178
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1820836216211319
# AVERAGE VAL LOSS: 0.32894015312194824
# #################
# # EPOCH 1179
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20341114699840546
# AVERAGE VAL LOSS: 0.35396960377693176
# #################
# # EPOCH 1180
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19188770651817322
# AVERAGE VAL LOSS: 0.3441307842731476
# #################
# # EPOCH 1181
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2048204243183136
# AVERAGE VAL LOSS: 0.30596408247947693
# #################
# # EPOCH 1182
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20190803706645966
# AVERAGE VAL LOSS: 0.4073651432991028
# #################
# # EPOCH 1183
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1981087625026703
# AVERAGE VAL LOSS: 0.30344489216804504
# #################
# # EPOCH 1184
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1935974359512329
# AVERAGE VAL LOSS: 0.36836230754852295
# #################
# # EPOCH 1185
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19502587616443634
# AVERAGE VAL LOSS: 0.33644333481788635
# #################
# # EPOCH 1186
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1952487975358963
# AVERAGE VAL LOSS: 0.3260510563850403
# #################
# # EPOCH 1187
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2071087658405304
# AVERAGE VAL LOSS: 0.32834550738334656
# #################
# # EPOCH 1188
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1947234570980072
# AVERAGE VAL LOSS: 0.3696412146091461
# #################
# # EPOCH 1189
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1943494975566864
# AVERAGE VAL LOSS: 0.30389121174812317
# #################
# # EPOCH 1190
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19716313481330872
# AVERAGE VAL LOSS: 0.3975941240787506
# #################
# # EPOCH 1191
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17689593136310577
# AVERAGE VAL LOSS: 0.3137435019016266
# #################
# # EPOCH 1192
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1790260523557663
# AVERAGE VAL LOSS: 0.33381617069244385
# #################
# # EPOCH 1193
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18990543484687805
# AVERAGE VAL LOSS: 0.35908082127571106
# #################
# # EPOCH 1194
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18657730519771576
# AVERAGE VAL LOSS: 0.3332313001155853
# #################
# # EPOCH 1195
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19732758402824402
# AVERAGE VAL LOSS: 0.31717315316200256
# #################
# # EPOCH 1196
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19039678573608398
# AVERAGE VAL LOSS: 0.38959071040153503
# #################
# # EPOCH 1197
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19288858771324158
# AVERAGE VAL LOSS: 0.2989853024482727
# #################
# # EPOCH 1198
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19027358293533325
# AVERAGE VAL LOSS: 0.37681296467781067
# #################
# # EPOCH 1199
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17970438301563263
# AVERAGE VAL LOSS: 0.32589659094810486
# #################
# # EPOCH 1200
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18413865566253662
# AVERAGE VAL LOSS: 0.3275531232357025
# #################
# # EPOCH 1201
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20577795803546906
# AVERAGE VAL LOSS: 0.3503769636154175
# #################
# # EPOCH 1202
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19163216650485992
# AVERAGE VAL LOSS: 0.34755197167396545
# #################
# # EPOCH 1203
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2012174129486084
# AVERAGE VAL LOSS: 0.3035716414451599
# #################
# # EPOCH 1204
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20084302127361298
# AVERAGE VAL LOSS: 0.4096585512161255
# #################
# # EPOCH 1205
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19178283214569092
# AVERAGE VAL LOSS: 0.3083629012107849
# #################
# # EPOCH 1206
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18833138048648834
# AVERAGE VAL LOSS: 0.35794639587402344
# #################
# # EPOCH 1207
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1950903832912445
# AVERAGE VAL LOSS: 0.3473447859287262
# #################
# # EPOCH 1208
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19519545137882233
# AVERAGE VAL LOSS: 0.3245869278907776
# #################
# # EPOCH 1209
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20580558478832245
# AVERAGE VAL LOSS: 0.32251980900764465
# #################
# # EPOCH 1210
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19469811022281647
# AVERAGE VAL LOSS: 0.37586522102355957
# #################
# # EPOCH 1211
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19425399601459503
# AVERAGE VAL LOSS: 0.2998781204223633
# #################
# # EPOCH 1212
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19538334012031555
# AVERAGE VAL LOSS: 0.39205917716026306
# #################
# # EPOCH 1213
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17597541213035583
# AVERAGE VAL LOSS: 0.31803497672080994
# #################
# # EPOCH 1214
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17829057574272156
# AVERAGE VAL LOSS: 0.3321617841720581
# #################
# # EPOCH 1215
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19198650121688843
# AVERAGE VAL LOSS: 0.3598078489303589
# #################
# # EPOCH 1216
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18604496121406555
# AVERAGE VAL LOSS: 0.3397715091705322
# #################
# # EPOCH 1217
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1958620846271515
# AVERAGE VAL LOSS: 0.31448280811309814
# #################
# # EPOCH 1218
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19158348441123962
# AVERAGE VAL LOSS: 0.3980427086353302
# #################
# # EPOCH 1219
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19113364815711975
# AVERAGE VAL LOSS: 0.30105435848236084
# #################
# # EPOCH 1220
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18763720989227295
# AVERAGE VAL LOSS: 0.36714524030685425
# #################
# # EPOCH 1221
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18189100921154022
# AVERAGE VAL LOSS: 0.33387988805770874
# #################
# # EPOCH 1222
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18662305176258087
# AVERAGE VAL LOSS: 0.3233799934387207
# #################
# # EPOCH 1223
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20767533779144287
# AVERAGE VAL LOSS: 0.3430967628955841
# #################
# # EPOCH 1224
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1918792724609375
# AVERAGE VAL LOSS: 0.3533400595188141
# #################
# # EPOCH 1225
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20028090476989746
# AVERAGE VAL LOSS: 0.3013698160648346
# #################
# # EPOCH 1226
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20075979828834534
# AVERAGE VAL LOSS: 0.4081653952598572
# #################
# # EPOCH 1227
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18842509388923645
# AVERAGE VAL LOSS: 0.314194917678833
# #################
# # EPOCH 1228
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1857949048280716
# AVERAGE VAL LOSS: 0.35118377208709717
# #################
# # EPOCH 1229
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19903042912483215
# AVERAGE VAL LOSS: 0.3557615280151367
# #################
# # EPOCH 1230
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1955682635307312
# AVERAGE VAL LOSS: 0.33019542694091797
# #################
# # EPOCH 1231
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20019745826721191
# AVERAGE VAL LOSS: 0.31586822867393494
# #################
# # EPOCH 1232
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19413770735263824
# AVERAGE VAL LOSS: 0.39097654819488525
# #################
# # EPOCH 1233
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19010598957538605
# AVERAGE VAL LOSS: 0.3001146614551544
# #################
# # EPOCH 1234
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1900050938129425
# AVERAGE VAL LOSS: 0.3769964277744293
# #################
# # EPOCH 1235
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17206928133964539
# AVERAGE VAL LOSS: 0.32474738359451294
# #################
# # EPOCH 1236
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17647787928581238
# AVERAGE VAL LOSS: 0.3227376639842987
# #################
# # EPOCH 1237
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19155335426330566
# AVERAGE VAL LOSS: 0.3587496280670166
# #################
# # EPOCH 1238
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18199124932289124
# AVERAGE VAL LOSS: 0.3433586657047272
# #################
# # EPOCH 1239
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1942402422428131
# AVERAGE VAL LOSS: 0.3119683563709259
# #################
# # EPOCH 1240
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19146087765693665
# AVERAGE VAL LOSS: 0.40216684341430664
# #################
# # EPOCH 1241
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19046974182128906
# AVERAGE VAL LOSS: 0.3076719343662262
# #################
# # EPOCH 1242
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18654312193393707
# AVERAGE VAL LOSS: 0.36210790276527405
# #################
# # EPOCH 1243
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19330933690071106
# AVERAGE VAL LOSS: 0.3456059694290161
# #################
# # EPOCH 1244
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19471821188926697
# AVERAGE VAL LOSS: 0.3248067796230316
# #################
# # EPOCH 1245
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20973697304725647
# AVERAGE VAL LOSS: 0.3277736008167267
# #################
# # EPOCH 1246
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19542598724365234
# AVERAGE VAL LOSS: 0.3694848120212555
# #################
# # EPOCH 1247
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19618472456932068
# AVERAGE VAL LOSS: 0.2998078763484955
# #################
# # EPOCH 1248
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19712476432323456
# AVERAGE VAL LOSS: 0.3972293436527252
# #################
# # EPOCH 1249
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17889054119586945
# AVERAGE VAL LOSS: 0.31938403844833374
# #################
# # EPOCH 1250
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17948107421398163
# AVERAGE VAL LOSS: 0.33787867426872253
# #################
# # EPOCH 1251
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1942628026008606
# AVERAGE VAL LOSS: 0.3601209819316864
# #################
# # EPOCH 1252
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18804249167442322
# AVERAGE VAL LOSS: 0.340526819229126
# #################
# # EPOCH 1253
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19529853761196136
# AVERAGE VAL LOSS: 0.3141806125640869
# #################
# # EPOCH 1254
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19208450615406036
# AVERAGE VAL LOSS: 0.40031683444976807
# #################
# # EPOCH 1255
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18875154852867126
# AVERAGE VAL LOSS: 0.3014317452907562
# #################
# # EPOCH 1256
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1857868880033493
# AVERAGE VAL LOSS: 0.3633245527744293
# #################
# # EPOCH 1257
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17859342694282532
# AVERAGE VAL LOSS: 0.33668437600135803
# #################
# # EPOCH 1258
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.183292418718338
# AVERAGE VAL LOSS: 0.3204875886440277
# #################
# # EPOCH 1259
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20284871757030487
# AVERAGE VAL LOSS: 0.3450859487056732
# #################
# # EPOCH 1260
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.188117116689682
# AVERAGE VAL LOSS: 0.35290536284446716
# #################
# # EPOCH 1261
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19765612483024597
# AVERAGE VAL LOSS: 0.30341824889183044
# #################
# # EPOCH 1262
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19786329567432404
# AVERAGE VAL LOSS: 0.4069410562515259
# #################
# # EPOCH 1263
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1876395344734192
# AVERAGE VAL LOSS: 0.3172440528869629
# #################
# # EPOCH 1264
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18492214381694794
# AVERAGE VAL LOSS: 0.35083281993865967
# #################
# # EPOCH 1265
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20068418979644775
# AVERAGE VAL LOSS: 0.3585973381996155
# #################
# # EPOCH 1266
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1955028772354126
# AVERAGE VAL LOSS: 0.33016255497932434
# #################
# # EPOCH 1267
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19761039316654205
# AVERAGE VAL LOSS: 0.31461507081985474
# #################
# # EPOCH 1268
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19319522380828857
# AVERAGE VAL LOSS: 0.3948639929294586
# #################
# # EPOCH 1269
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18723264336585999
# AVERAGE VAL LOSS: 0.3020643889904022
# #################
# # EPOCH 1270
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18715986609458923
# AVERAGE VAL LOSS: 0.3718659281730652
# #################
# # EPOCH 1271
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17094363272190094
# AVERAGE VAL LOSS: 0.33014973998069763
# #################
# # EPOCH 1272
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17570021748542786
# AVERAGE VAL LOSS: 0.32077062129974365
# #################
# # EPOCH 1273
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1913883537054062
# AVERAGE VAL LOSS: 0.357789546251297
# #################
# # EPOCH 1274
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1803499162197113
# AVERAGE VAL LOSS: 0.344306617975235
# #################
# # EPOCH 1275
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19262661039829254
# AVERAGE VAL LOSS: 0.3101455271244049
# #################
# # EPOCH 1276
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19081225991249084
# AVERAGE VAL LOSS: 0.4033607542514801
# #################
# # EPOCH 1277
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18802370131015778
# AVERAGE VAL LOSS: 0.31215161085128784
# #################
# # EPOCH 1278
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1847045123577118
# AVERAGE VAL LOSS: 0.3582247197628021
# #################
# # EPOCH 1279
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19574511051177979
# AVERAGE VAL LOSS: 0.35289260745048523
# #################
# # EPOCH 1280
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19484703242778778
# AVERAGE VAL LOSS: 0.32509249448776245
# #################
# # EPOCH 1281
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20426221191883087
# AVERAGE VAL LOSS: 0.32277238368988037
# #################
# # EPOCH 1282
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19336611032485962
# AVERAGE VAL LOSS: 0.3784893751144409
# #################
# # EPOCH 1283
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19135165214538574
# AVERAGE VAL LOSS: 0.30141735076904297
# #################
# # EPOCH 1284
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1918727606534958
# AVERAGE VAL LOSS: 0.38848429918289185
# #################
# # EPOCH 1285
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17472916841506958
# AVERAGE VAL LOSS: 0.32509753108024597
# #################
# # EPOCH 1286
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1769437938928604
# AVERAGE VAL LOSS: 0.3323099613189697
# #################
# # EPOCH 1287
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1928621530532837
# AVERAGE VAL LOSS: 0.3603051006793976
# #################
# # EPOCH 1288
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18431925773620605
# AVERAGE VAL LOSS: 0.34356018900871277
# #################
# # EPOCH 1289
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1928093433380127
# AVERAGE VAL LOSS: 0.3122140169143677
# #################
# # EPOCH 1290
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.190948024392128
# AVERAGE VAL LOSS: 0.40353405475616455
# #################
# # EPOCH 1291
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1863858997821808
# AVERAGE VAL LOSS: 0.3061996400356293
# #################
# # EPOCH 1292
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.183237224817276
# AVERAGE VAL LOSS: 0.35745376348495483
# #################
# # EPOCH 1293
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18471331894397736
# AVERAGE VAL LOSS: 0.3476582467556
# #################
# # EPOCH 1294
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1876649558544159
# AVERAGE VAL LOSS: 0.3210432231426239
# #################
# # EPOCH 1295
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20433363318443298
# AVERAGE VAL LOSS: 0.3341919481754303
# #################
# # EPOCH 1296
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19013933837413788
# AVERAGE VAL LOSS: 0.3641466796398163
# #################
# # EPOCH 1297
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19445882737636566
# AVERAGE VAL LOSS: 0.301624596118927
# #################
# # EPOCH 1298
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19510604441165924
# AVERAGE VAL LOSS: 0.3998771607875824
# #################
# # EPOCH 1299
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18042412400245667
# AVERAGE VAL LOSS: 0.3228473961353302
# #################
# # EPOCH 1300
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17980758845806122
# AVERAGE VAL LOSS: 0.34126463532447815
# #################
# # EPOCH 1301
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19660604000091553
# AVERAGE VAL LOSS: 0.3627232611179352
# #################
# # EPOCH 1302
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18948884308338165
# AVERAGE VAL LOSS: 0.33907273411750793
# #################
# # EPOCH 1303
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19292393326759338
# AVERAGE VAL LOSS: 0.31323838233947754
# #################
# # EPOCH 1304
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.191512793302536
# AVERAGE VAL LOSS: 0.4037361741065979
# #################
# # EPOCH 1305
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18478132784366608
# AVERAGE VAL LOSS: 0.30331969261169434
# #################
# # EPOCH 1306
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18273670971393585
# AVERAGE VAL LOSS: 0.3590121865272522
# #################
# # EPOCH 1307
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17431527376174927
# AVERAGE VAL LOSS: 0.34165042638778687
# #################
# # EPOCH 1308
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1789955198764801
# AVERAGE VAL LOSS: 0.3178093433380127
# #################
# # EPOCH 1309
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1969117522239685
# AVERAGE VAL LOSS: 0.34855979681015015
# #################
# # EPOCH 1310
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18348057568073273
# AVERAGE VAL LOSS: 0.35210326313972473
# #################
# # EPOCH 1311
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1940862238407135
# AVERAGE VAL LOSS: 0.30565065145492554
# #################
# # EPOCH 1312
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1938694417476654
# AVERAGE VAL LOSS: 0.4055993854999542
# #################
# # EPOCH 1313
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18612506985664368
# AVERAGE VAL LOSS: 0.32118213176727295
# #################
# # EPOCH 1314
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18308420479297638
# AVERAGE VAL LOSS: 0.35173988342285156
# #################
# # EPOCH 1315
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19982603192329407
# AVERAGE VAL LOSS: 0.36136287450790405
# #################
# # EPOCH 1316
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19360442459583282
# AVERAGE VAL LOSS: 0.33226072788238525
# #################
# # EPOCH 1317
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1930507868528366
# AVERAGE VAL LOSS: 0.31573572754859924
# #################
# # EPOCH 1318
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19032780826091766
# AVERAGE VAL LOSS: 0.39827606081962585
# #################
# # EPOCH 1319
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18340563774108887
# AVERAGE VAL LOSS: 0.3050241768360138
# #################
# # EPOCH 1320
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18298350274562836
# AVERAGE VAL LOSS: 0.36655738949775696
# #################
# # EPOCH 1321
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1693892478942871
# AVERAGE VAL LOSS: 0.33628228306770325
# #################
# # EPOCH 1322
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17439976334571838
# AVERAGE VAL LOSS: 0.3192945122718811
# #################
# # EPOCH 1323
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1897948831319809
# AVERAGE VAL LOSS: 0.35681411623954773
# #################
# # EPOCH 1324
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17830494046211243
# AVERAGE VAL LOSS: 0.34643059968948364
# #################
# # EPOCH 1325
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19028335809707642
# AVERAGE VAL LOSS: 0.30996397137641907
# #################
# # EPOCH 1326
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18900373578071594
# AVERAGE VAL LOSS: 0.40355244278907776
# #################
# # EPOCH 1327
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18543696403503418
# AVERAGE VAL LOSS: 0.31792885065078735
# #################
# # EPOCH 1328
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18242916464805603
# AVERAGE VAL LOSS: 0.3560350835323334
# #################
# # EPOCH 1329
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19718822836875916
# AVERAGE VAL LOSS: 0.3594442903995514
# #################
# # EPOCH 1330
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19347764551639557
# AVERAGE VAL LOSS: 0.3282169699668884
# #################
# # EPOCH 1331
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19661258161067963
# AVERAGE VAL LOSS: 0.3197275996208191
# #################
# # EPOCH 1332
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19008895754814148
# AVERAGE VAL LOSS: 0.3892630636692047
# #################
# # EPOCH 1333
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18542930483818054
# AVERAGE VAL LOSS: 0.3045175075531006
# #################
# # EPOCH 1334
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1852680742740631
# AVERAGE VAL LOSS: 0.37697458267211914
# #################
# # EPOCH 1335
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17078343033790588
# AVERAGE VAL LOSS: 0.3328295648097992
# #################
# # EPOCH 1336
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17485550045967102
# AVERAGE VAL LOSS: 0.3257793188095093
# #################
# # EPOCH 1337
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1910344809293747
# AVERAGE VAL LOSS: 0.3585379421710968
# #################
# # EPOCH 1338
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18021979928016663
# AVERAGE VAL LOSS: 0.3462565243244171
# #################
# # EPOCH 1339
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19036981463432312
# AVERAGE VAL LOSS: 0.31008708477020264
# #################
# # EPOCH 1340
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18929632008075714
# AVERAGE VAL LOSS: 0.4048333466053009
# #################
# # EPOCH 1341
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1840709149837494
# AVERAGE VAL LOSS: 0.31449663639068604
# #################
# # EPOCH 1342
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18127401173114777
# AVERAGE VAL LOSS: 0.35397231578826904
# #################
# # EPOCH 1343
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.193144753575325
# AVERAGE VAL LOSS: 0.3594750761985779
# #################
# # EPOCH 1344
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19121864438056946
# AVERAGE VAL LOSS: 0.32454049587249756
# #################
# # EPOCH 1345
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19798710942268372
# AVERAGE VAL LOSS: 0.3222380578517914
# #################
# # EPOCH 1346
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1894678920507431
# AVERAGE VAL LOSS: 0.3841392695903778
# #################
# # EPOCH 1347
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18685318529605865
# AVERAGE VAL LOSS: 0.30368053913116455
# #################
# # EPOCH 1348
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1869584619998932
# AVERAGE VAL LOSS: 0.3823831379413605
# #################
# # EPOCH 1349
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17228762805461884
# AVERAGE VAL LOSS: 0.33183395862579346
# #################
# # EPOCH 1350
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17555712163448334
# AVERAGE VAL LOSS: 0.32845544815063477
# #################
# # EPOCH 1351
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1926792562007904
# AVERAGE VAL LOSS: 0.36025387048721313
# #################
# # EPOCH 1352
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18181034922599792
# AVERAGE VAL LOSS: 0.3455812335014343
# #################
# # EPOCH 1353
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19011904299259186
# AVERAGE VAL LOSS: 0.30956631898880005
# #################
# # EPOCH 1354
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18976819515228271
# AVERAGE VAL LOSS: 0.4068518877029419
# #################
# # EPOCH 1355
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18251721560955048
# AVERAGE VAL LOSS: 0.31272217631340027
# #################
# # EPOCH 1356
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17998912930488586
# AVERAGE VAL LOSS: 0.3511781394481659
# #################
# # EPOCH 1357
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18964461982250214
# AVERAGE VAL LOSS: 0.3607895076274872
# #################
# # EPOCH 1358
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1892305314540863
# AVERAGE VAL LOSS: 0.3213579058647156
# #################
# # EPOCH 1359
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1989707201719284
# AVERAGE VAL LOSS: 0.32421234250068665
# #################
# # EPOCH 1360
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18912355601787567
# AVERAGE VAL LOSS: 0.3801698684692383
# #################
# # EPOCH 1361
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1880265772342682
# AVERAGE VAL LOSS: 0.30261531472206116
# #################
# # EPOCH 1362
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18824408948421478
# AVERAGE VAL LOSS: 0.386566698551178
# #################
# # EPOCH 1363
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1737520694732666
# AVERAGE VAL LOSS: 0.3319009840488434
# #################
# # EPOCH 1364
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17590996623039246
# AVERAGE VAL LOSS: 0.3311300277709961
# #################
# # EPOCH 1365
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19345593452453613
# AVERAGE VAL LOSS: 0.3618493676185608
# #################
# # EPOCH 1366
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18281902372837067
# AVERAGE VAL LOSS: 0.34540414810180664
# #################
# # EPOCH 1367
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18926037847995758
# AVERAGE VAL LOSS: 0.3096145987510681
# #################
# # EPOCH 1368
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18962635099887848
# AVERAGE VAL LOSS: 0.40819859504699707
# #################
# # EPOCH 1369
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1808343231678009
# AVERAGE VAL LOSS: 0.3112737536430359
# #################
# # EPOCH 1370
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1785866916179657
# AVERAGE VAL LOSS: 0.34858524799346924
# #################
# # EPOCH 1371
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18600626289844513
# AVERAGE VAL LOSS: 0.36193329095840454
# #################
# # EPOCH 1372
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18698649108409882
# AVERAGE VAL LOSS: 0.3193534016609192
# #################
# # EPOCH 1373
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19964499771595
# AVERAGE VAL LOSS: 0.3271578848361969
# #################
# # EPOCH 1374
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1885887086391449
# AVERAGE VAL LOSS: 0.37585073709487915
# #################
# # EPOCH 1375
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1892719268798828
# AVERAGE VAL LOSS: 0.3018331825733185
# #################
# # EPOCH 1376
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18945588171482086
# AVERAGE VAL LOSS: 0.3907288610935211
# #################
# # EPOCH 1377
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17554913461208344
# AVERAGE VAL LOSS: 0.332099050283432
# #################
# # EPOCH 1378
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1763424426317215
# AVERAGE VAL LOSS: 0.3343549966812134
# #################
# # EPOCH 1379
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19393301010131836
# AVERAGE VAL LOSS: 0.3632395565509796
# #################
# # EPOCH 1380
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18378499150276184
# AVERAGE VAL LOSS: 0.3456171154975891
# #################
# # EPOCH 1381
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18806341290473938
# AVERAGE VAL LOSS: 0.3103902339935303
# #################
# # EPOCH 1382
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18914835155010223
# AVERAGE VAL LOSS: 0.4092225730419159
# #################
# # EPOCH 1383
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17923107743263245
# AVERAGE VAL LOSS: 0.3099653124809265
# #################
# # EPOCH 1384
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17727936804294586
# AVERAGE VAL LOSS: 0.3462986350059509
# #################
# # EPOCH 1385
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18200531601905823
# AVERAGE VAL LOSS: 0.36240607500076294
# #################
# # EPOCH 1386
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18429118394851685
# AVERAGE VAL LOSS: 0.3176764249801636
# #################
# # EPOCH 1387
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19972378015518188
# AVERAGE VAL LOSS: 0.33144932985305786
# #################
# # EPOCH 1388
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1875738948583603
# AVERAGE VAL LOSS: 0.37065449357032776
# #################
# # EPOCH 1389
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1905616819858551
# AVERAGE VAL LOSS: 0.3015844523906708
# #################
# # EPOCH 1390
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19066086411476135
# AVERAGE VAL LOSS: 0.39521482586860657
# #################
# # EPOCH 1391
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17780916392803192
# AVERAGE VAL LOSS: 0.33226439356803894
# #################
# # EPOCH 1392
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1770167201757431
# AVERAGE VAL LOSS: 0.3381907045841217
# #################
# # EPOCH 1393
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1944468915462494
# AVERAGE VAL LOSS: 0.3646836280822754
# #################
# # EPOCH 1394
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18495281040668488
# AVERAGE VAL LOSS: 0.34554800391197205
# #################
# # EPOCH 1395
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18665529787540436
# AVERAGE VAL LOSS: 0.31171587109565735
# #################
# # EPOCH 1396
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18847419321537018
# AVERAGE VAL LOSS: 0.4100848138332367
# #################
# # EPOCH 1397
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17787596583366394
# AVERAGE VAL LOSS: 0.3087214231491089
# #################
# # EPOCH 1398
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17628559470176697
# AVERAGE VAL LOSS: 0.34453725814819336
# #################
# # EPOCH 1399
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17747007310390472
# AVERAGE VAL LOSS: 0.3617335855960846
# #################
# # EPOCH 1400
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18087059259414673
# AVERAGE VAL LOSS: 0.3158514201641083
# #################
# # EPOCH 1401
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19850438833236694
# AVERAGE VAL LOSS: 0.33772096037864685
# #################
# # EPOCH 1402
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18556636571884155
# AVERAGE VAL LOSS: 0.3643285632133484
# #################
# # EPOCH 1403
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19162529706954956
# AVERAGE VAL LOSS: 0.3022736608982086
# #################
# # EPOCH 1404
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19161878526210785
# AVERAGE VAL LOSS: 0.3999646008014679
# #################
# # EPOCH 1405
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18057551980018616
# AVERAGE VAL LOSS: 0.33220261335372925
# #################
# # EPOCH 1406
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1781250536441803
# AVERAGE VAL LOSS: 0.3427092730998993
# #################
# # EPOCH 1407
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19553303718566895
# AVERAGE VAL LOSS: 0.3663099706172943
# #################
# # EPOCH 1408
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1865868866443634
# AVERAGE VAL LOSS: 0.3443019688129425
# #################
# # EPOCH 1409
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1851525604724884
# AVERAGE VAL LOSS: 0.31331583857536316
# #################
# # EPOCH 1410
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18770721554756165
# AVERAGE VAL LOSS: 0.41083824634552
# #################
# # EPOCH 1411
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17691825330257416
# AVERAGE VAL LOSS: 0.30783018469810486
# #################
# # EPOCH 1412
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17593662440776825
# AVERAGE VAL LOSS: 0.3438117206096649
# #################
# # EPOCH 1413
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17261353135108948
# AVERAGE VAL LOSS: 0.359428346157074
# #################
# # EPOCH 1414
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17665311694145203
# AVERAGE VAL LOSS: 0.31347668170928955
# #################
# # EPOCH 1415
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19481489062309265
# AVERAGE VAL LOSS: 0.3463224470615387
# #################
# # EPOCH 1416
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18181951344013214
# AVERAGE VAL LOSS: 0.3574298620223999
# #################
# # EPOCH 1417
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19137971103191376
# AVERAGE VAL LOSS: 0.3047412037849426
# #################
# # EPOCH 1418
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19126512110233307
# AVERAGE VAL LOSS: 0.40405917167663574
# #################
# # EPOCH 1419
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1831829845905304
# AVERAGE VAL LOSS: 0.3315158188343048
# #################
# # EPOCH 1420
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17960131168365479
# AVERAGE VAL LOSS: 0.34775111079216003
# #################
# # EPOCH 1421
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19806894659996033
# AVERAGE VAL LOSS: 0.368110328912735
# #################
# # EPOCH 1422
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18876376748085022
# AVERAGE VAL LOSS: 0.34085407853126526
# #################
# # EPOCH 1423
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18371616303920746
# AVERAGE VAL LOSS: 0.31447821855545044
# #################
# # EPOCH 1424
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18695604801177979
# AVERAGE VAL LOSS: 0.41145437955856323
# #################
# # EPOCH 1425
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17628519237041473
# AVERAGE VAL LOSS: 0.30811089277267456
# #################
# # EPOCH 1426
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17647774517536163
# AVERAGE VAL LOSS: 0.3446829319000244
# #################
# # EPOCH 1427
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1685418337583542
# AVERAGE VAL LOSS: 0.3560689091682434
# #################
# # EPOCH 1428
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1726190447807312
# AVERAGE VAL LOSS: 0.31058254837989807
# #################
# # EPOCH 1429
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1887224018573761
# AVERAGE VAL LOSS: 0.3555590510368347
# #################
# # EPOCH 1430
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17631079256534576
# AVERAGE VAL LOSS: 0.3516167402267456
# #################
# # EPOCH 1431
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1880008429288864
# AVERAGE VAL LOSS: 0.30912700295448303
# #################
# # EPOCH 1432
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1877383440732956
# AVERAGE VAL LOSS: 0.4053739309310913
# #################
# # EPOCH 1433
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18318185210227966
# AVERAGE VAL LOSS: 0.33001700043678284
# #################
# # EPOCH 1434
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1799258589744568
# AVERAGE VAL LOSS: 0.352081298828125
# #################
# # EPOCH 1435
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.201670840382576
# AVERAGE VAL LOSS: 0.3705423176288605
# #################
# # EPOCH 1436
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1908341348171234
# AVERAGE VAL LOSS: 0.33596155047416687
# #################
# # EPOCH 1437
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18335001170635223
# AVERAGE VAL LOSS: 0.31428664922714233
# #################
# # EPOCH 1438
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18670085072517395
# AVERAGE VAL LOSS: 0.4119279384613037
# #################
# # EPOCH 1439
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17603032290935516
# AVERAGE VAL LOSS: 0.3092727065086365
# #################
# # EPOCH 1440
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17736276984214783
# AVERAGE VAL LOSS: 0.34759628772735596
# #################
# # EPOCH 1441
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16681469976902008
# AVERAGE VAL LOSS: 0.35413074493408203
# #################
# # EPOCH 1442
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17090021073818207
# AVERAGE VAL LOSS: 0.3094593584537506
# #################
# # EPOCH 1443
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18527847528457642
# AVERAGE VAL LOSS: 0.3605274558067322
# #################
# # EPOCH 1444
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17287293076515198
# AVERAGE VAL LOSS: 0.3484468162059784
# #################
# # EPOCH 1445
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18502309918403625
# AVERAGE VAL LOSS: 0.3113567531108856
# #################
# # EPOCH 1446
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1845243275165558
# AVERAGE VAL LOSS: 0.4046224057674408
# #################
# # EPOCH 1447
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18190880119800568
# AVERAGE VAL LOSS: 0.32960811257362366
# #################
# # EPOCH 1448
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17915736138820648
# AVERAGE VAL LOSS: 0.3543241322040558
# #################
# # EPOCH 1449
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20332586765289307
# AVERAGE VAL LOSS: 0.372564435005188
# #################
# # EPOCH 1450
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19159647822380066
# AVERAGE VAL LOSS: 0.33441394567489624
# #################
# # EPOCH 1451
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18372465670108795
# AVERAGE VAL LOSS: 0.3140160143375397
# #################
# # EPOCH 1452
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18681089580059052
# AVERAGE VAL LOSS: 0.41236430406570435
# #################
# # EPOCH 1453
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17599953711032867
# AVERAGE VAL LOSS: 0.3094565272331238
# #################
# # EPOCH 1454
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17730793356895447
# AVERAGE VAL LOSS: 0.3494647741317749
# #################
# # EPOCH 1455
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1668730229139328
# AVERAGE VAL LOSS: 0.3549751341342926
# #################
# # EPOCH 1456
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17104975879192352
# AVERAGE VAL LOSS: 0.3107021749019623
# #################
# # EPOCH 1457
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18651261925697327
# AVERAGE VAL LOSS: 0.3604605793952942
# #################
# # EPOCH 1458
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1737051010131836
# AVERAGE VAL LOSS: 0.34801995754241943
# #################
# # EPOCH 1459
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18687307834625244
# AVERAGE VAL LOSS: 0.3095671236515045
# #################
# # EPOCH 1460
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18617688119411469
# AVERAGE VAL LOSS: 0.4053080081939697
# #################
# # EPOCH 1461
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18447500467300415
# AVERAGE VAL LOSS: 0.3309885263442993
# #################
# # EPOCH 1462
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18065164983272552
# AVERAGE VAL LOSS: 0.3561204671859741
# #################
# # EPOCH 1463
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20438747107982635
# AVERAGE VAL LOSS: 0.37168705463409424
# #################
# # EPOCH 1464
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19082428514957428
# AVERAGE VAL LOSS: 0.3386266529560089
# #################
# # EPOCH 1465
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18030811846256256
# AVERAGE VAL LOSS: 0.3155043125152588
# #################
# # EPOCH 1466
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18569238483905792
# AVERAGE VAL LOSS: 0.4143022894859314
# #################
# # EPOCH 1467
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17440560460090637
# AVERAGE VAL LOSS: 0.31067758798599243
# #################
# # EPOCH 1468
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1766630858182907
# AVERAGE VAL LOSS: 0.3422362506389618
# #################
# # EPOCH 1469
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16671833395957947
# AVERAGE VAL LOSS: 0.3583897650241852
# #################
# # EPOCH 1470
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16955803334712982
# AVERAGE VAL LOSS: 0.30720797181129456
# #################
# # EPOCH 1471
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1822357177734375
# AVERAGE VAL LOSS: 0.3621123731136322
# #################
# # EPOCH 1472
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16974864900112152
# AVERAGE VAL LOSS: 0.3491639196872711
# #################
# # EPOCH 1473
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18113501369953156
# AVERAGE VAL LOSS: 0.31400278210639954
# #################
# # EPOCH 1474
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18063412606716156
# AVERAGE VAL LOSS: 0.4029206335544586
# #################
# # EPOCH 1475
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.179436594247818
# AVERAGE VAL LOSS: 0.3324704170227051
# #################
# # EPOCH 1476
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17754782736301422
# AVERAGE VAL LOSS: 0.35468560457229614
# #################
# # EPOCH 1477
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20731456577777863
# AVERAGE VAL LOSS: 0.3763214349746704
# #################
# # EPOCH 1478
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19221195578575134
# AVERAGE VAL LOSS: 0.33549898862838745
# #################
# # EPOCH 1479
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18304426968097687
# AVERAGE VAL LOSS: 0.3109472095966339
# #################
# # EPOCH 1480
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18822965025901794
# AVERAGE VAL LOSS: 0.418183833360672
# #################
# # EPOCH 1481
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17488333582878113
# AVERAGE VAL LOSS: 0.3095293939113617
# #################
# # EPOCH 1482
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17710237205028534
# AVERAGE VAL LOSS: 0.34445780515670776
# #################
# # EPOCH 1483
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16791477799415588
# AVERAGE VAL LOSS: 0.3620574176311493
# #################
# # EPOCH 1484
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17062678933143616
# AVERAGE VAL LOSS: 0.3106144666671753
# #################
# # EPOCH 1485
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18611235916614532
# AVERAGE VAL LOSS: 0.3602543771266937
# #################
# # EPOCH 1486
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17245268821716309
# AVERAGE VAL LOSS: 0.3481179475784302
# #################
# # EPOCH 1487
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18587332963943481
# AVERAGE VAL LOSS: 0.30816298723220825
# #################
# # EPOCH 1488
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18502965569496155
# AVERAGE VAL LOSS: 0.4036787152290344
# #################
# # EPOCH 1489
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18575672805309296
# AVERAGE VAL LOSS: 0.3355814218521118
# #################
# # EPOCH 1490
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1809549182653427
# AVERAGE VAL LOSS: 0.3580681085586548
# #################
# # EPOCH 1491
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20644895732402802
# AVERAGE VAL LOSS: 0.3716224431991577
# #################
# # EPOCH 1492
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19026999175548553
# AVERAGE VAL LOSS: 0.3463648855686188
# #################
# # EPOCH 1493
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17807772755622864
# AVERAGE VAL LOSS: 0.3157065808773041
# #################
# # EPOCH 1494
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18606752157211304
# AVERAGE VAL LOSS: 0.4164239764213562
# #################
# # EPOCH 1495
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1718887984752655
# AVERAGE VAL LOSS: 0.31058478355407715
# #################
# # EPOCH 1496
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1751127541065216
# AVERAGE VAL LOSS: 0.333673357963562
# #################
# # EPOCH 1497
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16773287951946259
# AVERAGE VAL LOSS: 0.36677080392837524
# #################
# # EPOCH 1498
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1682392805814743
# AVERAGE VAL LOSS: 0.3091067671775818
# #################
# # EPOCH 1499
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17906007170677185
# AVERAGE VAL LOSS: 0.3594471216201782
# #################
# # EPOCH 1500
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16608765721321106
# AVERAGE VAL LOSS: 0.35245341062545776
# #################
# # EPOCH 1501
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17521435022354126
# AVERAGE VAL LOSS: 0.31433025002479553
# #################
# # EPOCH 1502
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1750253140926361
# AVERAGE VAL LOSS: 0.3967724144458771
# #################
# # EPOCH 1503
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17198237776756287
# AVERAGE VAL LOSS: 0.3366076350212097
# #################
# # EPOCH 1504
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17310366034507751
# AVERAGE VAL LOSS: 0.349440336227417
# #################
# # EPOCH 1505
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20836007595062256
# AVERAGE VAL LOSS: 0.38219836354255676
# #################
# # EPOCH 1506
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19246205687522888
# AVERAGE VAL LOSS: 0.33342206478118896
# #################
# # EPOCH 1507
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1895386278629303
# AVERAGE VAL LOSS: 0.3029516339302063
# #################
# # EPOCH 1508
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19293376803398132
# AVERAGE VAL LOSS: 0.42212042212486267
# #################
# # EPOCH 1509
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1762121170759201
# AVERAGE VAL LOSS: 0.3077230155467987
# #################
# # EPOCH 1510
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1764158308506012
# AVERAGE VAL LOSS: 0.3504127264022827
# #################
# # EPOCH 1511
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17412088811397552
# AVERAGE VAL LOSS: 0.3722207546234131
# #################
# # EPOCH 1512
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1782294511795044
# AVERAGE VAL LOSS: 0.3210155665874481
# #################
# # EPOCH 1513
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.20246025919914246
# AVERAGE VAL LOSS: 0.3465298116207123
# #################
# # EPOCH 1514
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18559026718139648
# AVERAGE VAL LOSS: 0.3515557646751404
# #################
# # EPOCH 1515
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19751067459583282
# AVERAGE VAL LOSS: 0.291309654712677
# #################
# # EPOCH 1516
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19534717500209808
# AVERAGE VAL LOSS: 0.40569472312927246
# #################
# # EPOCH 1517
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19408932328224182
# AVERAGE VAL LOSS: 0.34527286887168884
# #################
# # EPOCH 1518
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17939451336860657
# AVERAGE VAL LOSS: 0.35874080657958984
# #################
# # EPOCH 1519
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1855248510837555
# AVERAGE VAL LOSS: 0.36515355110168457
# #################
# # EPOCH 1520
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1831665188074112
# AVERAGE VAL LOSS: 0.35931268334388733
# #################
# # EPOCH 1521
# ...
# AVERAGE VAL LOSS: 0.3253827691078186
# #################
# # EPOCH 1882
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16735020279884338
# AVERAGE VAL LOSS: 0.39012107253074646
# #################
# # EPOCH 1883
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1612023115158081
# AVERAGE VAL LOSS: 0.3208445906639099
# #################
# # EPOCH 1884
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1601829081773758
# AVERAGE VAL LOSS: 0.3448081612586975
# #################
# # EPOCH 1885
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17117561399936676
# AVERAGE VAL LOSS: 0.37744563817977905
# #################
# # EPOCH 1886
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17398053407669067
# AVERAGE VAL LOSS: 0.3350863754749298
# #################
# # EPOCH 1887
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19058550894260406
# AVERAGE VAL LOSS: 0.33601003885269165
# #################
# # EPOCH 1888
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18066568672657013
# AVERAGE VAL LOSS: 0.37268924713134766
# #################
# # EPOCH 1889
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1769011914730072
# AVERAGE VAL LOSS: 0.3078678548336029
# #################
# # EPOCH 1890
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17607037723064423
# AVERAGE VAL LOSS: 0.3824087977409363
# #################
# # EPOCH 1891
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17263665795326233
# AVERAGE VAL LOSS: 0.3601272702217102
# #################
# # EPOCH 1892
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1676030308008194
# AVERAGE VAL LOSS: 0.34597671031951904
# #################
# # EPOCH 1893
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17518006265163422
# AVERAGE VAL LOSS: 0.3573765158653259
# #################
# # EPOCH 1894
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1691293716430664
# AVERAGE VAL LOSS: 0.36447498202323914
# #################
# # EPOCH 1895
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16959695518016815
# AVERAGE VAL LOSS: 0.3164083957672119
# #################
# # EPOCH 1896
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1698201596736908
# AVERAGE VAL LOSS: 0.39013880491256714
# #################
# # EPOCH 1897
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16034743189811707
# AVERAGE VAL LOSS: 0.3350285291671753
# #################
# # EPOCH 1898
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16347886621952057
# AVERAGE VAL LOSS: 0.33840835094451904
# #################
# # EPOCH 1899
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18555915355682373
# AVERAGE VAL LOSS: 0.3830966651439667
# #################
# # EPOCH 1900
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1761661320924759
# AVERAGE VAL LOSS: 0.3372970223426819
# #################
# # EPOCH 1901
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17772521078586578
# AVERAGE VAL LOSS: 0.3145418167114258
# #################
# # EPOCH 1902
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17831392586231232
# AVERAGE VAL LOSS: 0.4088079035282135
# #################
# # EPOCH 1903
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16820594668388367
# AVERAGE VAL LOSS: 0.3195905387401581
# #################
# # EPOCH 1904
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16752848029136658
# AVERAGE VAL LOSS: 0.34913352131843567
# #################
# # EPOCH 1905
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17545992136001587
# AVERAGE VAL LOSS: 0.3818316161632538
# #################
# # EPOCH 1906
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17688007652759552
# AVERAGE VAL LOSS: 0.3176000714302063
# #################
# # EPOCH 1907
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1923086941242218
# AVERAGE VAL LOSS: 0.3370139002799988
# #################
# # EPOCH 1908
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1831721067428589
# AVERAGE VAL LOSS: 0.3694760799407959
# #################
# # EPOCH 1909
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17757415771484375
# AVERAGE VAL LOSS: 0.30660998821258545
# #################
# # EPOCH 1910
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17782273888587952
# AVERAGE VAL LOSS: 0.39035123586654663
# #################
# # EPOCH 1911
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17285411059856415
# AVERAGE VAL LOSS: 0.36189883947372437
# #################
# # EPOCH 1912
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16615360975265503
# AVERAGE VAL LOSS: 0.3503521978855133
# #################
# # EPOCH 1913
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17663948237895966
# AVERAGE VAL LOSS: 0.3653012812137604
# #################
# # EPOCH 1914
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1713515669107437
# AVERAGE VAL LOSS: 0.35783442854881287
# #################
# # EPOCH 1915
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17116133868694305
# AVERAGE VAL LOSS: 0.31319642066955566
# #################
# # EPOCH 1916
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17140011489391327
# AVERAGE VAL LOSS: 0.3956550359725952
# #################
# # EPOCH 1917
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16014517843723297
# AVERAGE VAL LOSS: 0.32759395241737366
# #################
# # EPOCH 1918
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16160549223423004
# AVERAGE VAL LOSS: 0.3398420810699463
# #################
# # EPOCH 1919
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17941635847091675
# AVERAGE VAL LOSS: 0.3874411880970001
# #################
# # EPOCH 1920
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1768721044063568
# AVERAGE VAL LOSS: 0.33358505368232727
# #################
# # EPOCH 1921
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18459683656692505
# AVERAGE VAL LOSS: 0.32137882709503174
# #################
# # EPOCH 1922
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18078526854515076
# AVERAGE VAL LOSS: 0.3933570981025696
# #################
# # EPOCH 1923
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17158833146095276
# AVERAGE VAL LOSS: 0.309479683637619
# #################
# # EPOCH 1924
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17044518887996674
# AVERAGE VAL LOSS: 0.36596983671188354
# #################
# # EPOCH 1925
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17188696563243866
# AVERAGE VAL LOSS: 0.3717535734176636
# #################
# # EPOCH 1926
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17041300237178802
# AVERAGE VAL LOSS: 0.3345874547958374
# #################
# # EPOCH 1927
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18214988708496094
# AVERAGE VAL LOSS: 0.346993088722229
# #################
# # EPOCH 1928
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1729869693517685
# AVERAGE VAL LOSS: 0.36502620577812195
# #################
# # EPOCH 1929
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17342513799667358
# AVERAGE VAL LOSS: 0.30611392855644226
# #################
# # EPOCH 1930
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17288526892662048
# AVERAGE VAL LOSS: 0.3864641487598419
# #################
# # EPOCH 1931
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16658088564872742
# AVERAGE VAL LOSS: 0.35260432958602905
# #################
# # EPOCH 1932
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16657355427742004
# AVERAGE VAL LOSS: 0.343807578086853
# #################
# # EPOCH 1933
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18454958498477936
# AVERAGE VAL LOSS: 0.3706914782524109
# #################
# # EPOCH 1934
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17403128743171692
# AVERAGE VAL LOSS: 0.3486863374710083
# #################
# # EPOCH 1935
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.173105388879776
# AVERAGE VAL LOSS: 0.30989062786102295
# #################
# # EPOCH 1936
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.175144225358963
# AVERAGE VAL LOSS: 0.4052811861038208
# #################
# # EPOCH 1937
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.161375030875206
# AVERAGE VAL LOSS: 0.326558381319046
# #################
# # EPOCH 1938
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1622883826494217
# AVERAGE VAL LOSS: 0.3396599292755127
# #################
# # EPOCH 1939
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17727570235729218
# AVERAGE VAL LOSS: 0.39311254024505615
# #################
# # EPOCH 1940
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17937301099300385
# AVERAGE VAL LOSS: 0.32520171999931335
# #################
# # EPOCH 1941
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19113507866859436
# AVERAGE VAL LOSS: 0.32362815737724304
# #################
# # EPOCH 1942
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1848752796649933
# AVERAGE VAL LOSS: 0.3816986083984375
# #################
# # EPOCH 1943
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17324519157409668
# AVERAGE VAL LOSS: 0.30134814977645874
# #################
# # EPOCH 1944
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17311757802963257
# AVERAGE VAL LOSS: 0.3806382119655609
# #################
# # EPOCH 1945
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17012245953083038
# AVERAGE VAL LOSS: 0.3715943396091461
# #################
# # EPOCH 1946
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1662934124469757
# AVERAGE VAL LOSS: 0.35238298773765564
# #################
# # EPOCH 1947
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18151196837425232
# AVERAGE VAL LOSS: 0.3622282147407532
# #################
# # EPOCH 1948
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17179881036281586
# AVERAGE VAL LOSS: 0.3559800982475281
# #################
# # EPOCH 1949
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17465172708034515
# AVERAGE VAL LOSS: 0.30174779891967773
# #################
# # EPOCH 1950
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1733180582523346
# AVERAGE VAL LOSS: 0.3928413391113281
# #################
# # EPOCH 1951
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16169926524162292
# AVERAGE VAL LOSS: 0.33839425444602966
# #################
# # EPOCH 1952
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16374626755714417
# AVERAGE VAL LOSS: 0.34390249848365784
# #################
# # EPOCH 1953
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18335974216461182
# AVERAGE VAL LOSS: 0.38339823484420776
# #################
# # EPOCH 1954
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17522074282169342
# AVERAGE VAL LOSS: 0.3413175046443939
# #################
# # EPOCH 1955
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17584732174873352
# AVERAGE VAL LOSS: 0.31480616331100464
# #################
# # EPOCH 1956
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17705340683460236
# AVERAGE VAL LOSS: 0.4079092741012573
# #################
# # EPOCH 1957
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1661737561225891
# AVERAGE VAL LOSS: 0.31668373942375183
# #################
# # EPOCH 1958
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16546392440795898
# AVERAGE VAL LOSS: 0.347284734249115
# #################
# # EPOCH 1959
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17078164219856262
# AVERAGE VAL LOSS: 0.3817079961299896
# #################
# # EPOCH 1960
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17462018132209778
# AVERAGE VAL LOSS: 0.3198081851005554
# #################
# # EPOCH 1961
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1954110562801361
# AVERAGE VAL LOSS: 0.3440832495689392
# #################
# # EPOCH 1962
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.184556245803833
# AVERAGE VAL LOSS: 0.35780128836631775
# #################
# # EPOCH 1963
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18067020177841187
# AVERAGE VAL LOSS: 0.30493149161338806
# #################
# # EPOCH 1964
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1808081567287445
# AVERAGE VAL LOSS: 0.39564865827560425
# #################
# # EPOCH 1965
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17455872893333435
# AVERAGE VAL LOSS: 0.36327871680259705
# #################
# # EPOCH 1966
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.164749413728714
# AVERAGE VAL LOSS: 0.35853636264801025
# #################
# # EPOCH 1967
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1705564707517624
# AVERAGE VAL LOSS: 0.3681347668170929
# #################
# # EPOCH 1968
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16993162035942078
# AVERAGE VAL LOSS: 0.35727617144584656
# #################
# # EPOCH 1969
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16831566393375397
# AVERAGE VAL LOSS: 0.3195172846317291
# #################
# # EPOCH 1970
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1679821014404297
# AVERAGE VAL LOSS: 0.3920040726661682
# #################
# # EPOCH 1971
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.15909285843372345
# AVERAGE VAL LOSS: 0.32225194573402405
# #################
# # EPOCH 1972
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1592046618461609
# AVERAGE VAL LOSS: 0.34310951828956604
# #################
# # EPOCH 1973
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1709451675415039
# AVERAGE VAL LOSS: 0.3824557065963745
# #################
# # EPOCH 1974
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17407329380512238
# AVERAGE VAL LOSS: 0.3344401717185974
# #################
# # EPOCH 1975
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.19033679366111755
# AVERAGE VAL LOSS: 0.3341611325740814
# #################
# # EPOCH 1976
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18106307089328766
# AVERAGE VAL LOSS: 0.370178759098053
# #################
# # EPOCH 1977
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17480675876140594
# AVERAGE VAL LOSS: 0.3062114119529724
# #################
# # EPOCH 1978
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17436547577381134
# AVERAGE VAL LOSS: 0.38214007019996643
# #################
# # EPOCH 1979
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1709180474281311
# AVERAGE VAL LOSS: 0.36517032980918884
# #################
# # EPOCH 1980
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16568756103515625
# AVERAGE VAL LOSS: 0.3506165146827698
# #################
# # EPOCH 1981
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17332355678081512
# AVERAGE VAL LOSS: 0.3586321175098419
# #################
# # EPOCH 1982
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16784779727458954
# AVERAGE VAL LOSS: 0.36222922801971436
# #################
# # EPOCH 1983
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16838781535625458
# AVERAGE VAL LOSS: 0.3145919144153595
# #################
# # EPOCH 1984
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16826248168945312
# AVERAGE VAL LOSS: 0.38771137595176697
# #################
# # EPOCH 1985
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1587584763765335
# AVERAGE VAL LOSS: 0.3365117907524109
# #################
# # EPOCH 1986
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16198407113552094
# AVERAGE VAL LOSS: 0.34088417887687683
# #################
# # EPOCH 1987
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.18255722522735596
# AVERAGE VAL LOSS: 0.38237273693084717
# #################
# # EPOCH 1988
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1747005730867386
# AVERAGE VAL LOSS: 0.3380080461502075
# #################
# # EPOCH 1989
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1772688925266266
# AVERAGE VAL LOSS: 0.316791832447052
# #################
# # EPOCH 1990
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1771177351474762
# AVERAGE VAL LOSS: 0.40145787596702576
# #################
# # EPOCH 1991
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1666250228881836
# AVERAGE VAL LOSS: 0.3209303617477417
# #################
# # EPOCH 1992
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16616186499595642
# AVERAGE VAL LOSS: 0.3539469838142395
# #################
# # EPOCH 1993
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17291009426116943
# AVERAGE VAL LOSS: 0.37800630927085876
# #################
# # EPOCH 1994
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17403502762317657
# AVERAGE VAL LOSS: 0.32333168387413025
# #################
# # EPOCH 1995
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1868029683828354
# AVERAGE VAL LOSS: 0.33852657675743103
# #################
# # EPOCH 1996
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17833475768566132
# AVERAGE VAL LOSS: 0.3657163679599762
# #################
# # EPOCH 1997
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.1730756163597107
# AVERAGE VAL LOSS: 0.30773207545280457
# #################
# # EPOCH 1998
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.17387400567531586
# AVERAGE VAL LOSS: 0.3872288763523102
# #################
# # EPOCH 1999
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.16819819808006287
# AVERAGE VAL LOSS: 0.3614221513271332

# %%
len(train_loss_log)
# Out:
# 6000

# %% [markdown]
# **Plot** **loss**

# %%
# Define the list of losses for each split 
j=0
for i in range (0,6000,2000):
  j+=1
  globals()['train_loss_log%d' % j] =train_loss_log[i:i+2000]
  globals()['val_loss_log%d' % j] =val_loss_log[i:i+2000]

# %%
TrainFold1Loss=train_loss_log1[-1]
ValFold1Loss=val_loss_log1[-1]
TrainFold2Loss=train_loss_log2[-1]
ValFold2Loss=val_loss_log2[-1]
TrainFold3Loss=train_loss_log3[-1]
ValFold3Loss=val_loss_log3[-1]
print('FOLD1')
print(TrainFold1Loss)
print(ValFold1Loss)
print('FOLD2')
print(TrainFold2Loss)
print(ValFold2Loss)
print('FOLD3')
print(TrainFold3Loss)
print(ValFold3Loss)
# Out:
# FOLD1
# 0.2429488
# 0.4173703
# FOLD2
# 0.13003038
# 0.58391374
# FOLD3
# 0.1681982
# 0.36142215

# %%
# Plot losses
plt.figure(figsize=(12,8))

plt.semilogy(train_loss_log3, label='Train loss') #feel free to change 7 to any other number between 1 and 10
plt.semilogy(val_loss_log3, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the *final* model**

# %%
### Reload the network state
# Load the state dict previously saved
net = Net(Ni, Nh1, Nh2, No) 
net_state_dict = torch.load('net_parameters.torch 3')
# Update the network parameters
net.load_state_dict(net_state_dict)
net=net.to(device)
# Out:
# Network initialized

# %%
x_vec=train_df['input'].values
x_vec=torch.tensor(x_vec)
x_vec = x_vec.to(device)
x_vec = x_vec.unsqueeze(-1)

with torch.no_grad():
  y_vec = net(x_vec.float())

y_vec= y_vec.squeeze().cpu().numpy()
x_vec = x_vec.squeeze().cpu().numpy()

plt.figure(figsize=(12,8))
plt.scatter(x_vec, y_vec, label='Network output predictions')
plt.scatter(train_df.input, train_df.label, label='Training points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **Testing**

# %%
test_df = pd.read_csv('/content/regression_dataset/test_data.csv')
print(test_df)
print(len(test_df))
# Out:
#        input     label
# 0  -0.623168  2.908782
# 1   4.613433  4.961119
# 2   4.233314  3.403159
# 3  -4.555919 -0.606397
# 4   2.894684  1.397028
# ..       ...       ...
# 95 -2.029013  4.130353
# 96  0.313855  1.835889
# 97 -3.108990  3.434612
# 98 -0.213557  2.281842
# 99  3.842187  2.013707
#
# [100 rows x 2 columns]
# 100

# %%
#Plotting test set
fig = plt.figure(figsize=(12,8))
plt.scatter(test_df.input, test_df.label, label='Test points')
plt.xlabel('input')
plt.ylabel('label')
plt.legend()
plt.show()

# %%
class CsvDataset(Dataset):

  def __init__(self, csv_file, transform=None):
    """
    Args:
        csv_file (string): Path to the csv file.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.transform = transform
    # Read the file and split the lines in a list
    with open(csv_file, 'r') as f:
      next(f)
      lines = f.read().split('\n')
    # Get x and y values from each line and append to self.data
    self.data = []
    i=0
    for line in lines:
      if(i<100):
        sample = line.split(',')
        self.data.append((float(sample[0]), float(sample[1])))
        i+=1
    print(self.data)
    # Now self.data contains all our dataset.
    # Each element of the list self.data is a tuple: (input, output)

  def __len__(self):
    # The length of the dataset is simply the length of the self.data list
    return len(self.data)

  def __getitem__(self, idx):
    # Our sample is the element idx of the list self.data
    sample = self.data[idx]
    if self.transform:
        sample = self.transform(sample)
    return sample

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.Tensor([x]).float(),
                torch.Tensor([y]).float())

# %%
composed_transform = transforms.Compose([ToTensor()])
test_dataset  = CsvDataset('/content/regression_dataset/test_data.csv', transform=composed_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = len(test_dataset), shuffle = False,num_workers=0)
# Out:
# [(-0.6231675406149462, 2.9087815185148878), (4.613433376388237, 4.961118788436131), (4.233314376526877, 3.4031590776543372), (-4.555919250097348, -0.6063969972731267), (2.894684263706755, 1.397027611825461), (-4.896136646330326, -2.4351314439225202), (-1.9246747630539773, 4.375016310250146), (-3.1486955626704427, 3.6421525793126723), (1.5942763905899806, 2.6913378351822357), (-0.30798328423268373, 2.5373858074822873), (0.2875453988824379, 1.822509291506494), (-3.31411378326342, 3.3058175248623964), (-4.901344736490502, -2.4125457906705106), (1.9832678591645525, 2.7989902399122943), (-0.48758796303868035, 2.6897037174426677), (2.5672125613761114, 2.30418343813432), (3.8412844865894638, 2.1385751906720984), (4.558564907220784, 4.76823560570816), (-2.1034052936211656, 4.055769652380439), (-1.3323843534509883, 3.6948092189185036), (-2.8722684427772514, 4.022905514736294), (-2.9449007426141205, 3.699348763073657), (-0.679382382098769, 3.0289438661539854), (1.940698214750225, 2.842032422433958), (4.5576822733127695, 4.535622328595481), (2.2806123514926346, 2.492453761827909), (1.8123390088773226, 2.643829327757032), (-0.9733544959340188, 3.481777585049891), (-2.7940401769455505, 3.8792968040380944), (0.8443033807006506, 1.7067240808618913), (-2.9789490901272586, 3.6485096725947415), (-4.365522213903606, 0.35675632240763877), (1.9618742381972236, 2.9019782364901676), (-3.7476733074997415, 2.218526037199633), (-1.736294982361719, 4.120083296269987), (-0.5172864510000421, 2.8557469374482807), (1.2200355193472667, 1.962430711395826), (3.451990095152306, 1.194139236838943), (1.8803683619167302, 2.656486462748123), (-2.634017715375372, 4.132280611949939), (-1.4791039828059551, 3.7763533073181357), (-2.2389733760020802, 4.265174303575622), (-0.007337115144826711, 2.215781267762186), (-4.961926412324433, -2.5905378700764348), (2.571601012411705, 1.9113982649834662), (-1.1838984669156116, 3.6269051405149204), (0.2645091207584933, 1.6548395463068377), (1.7807732901628883, 2.778253679793101), (0.8921075497179984, 1.5993813594850677), (4.000049452157944, 2.549096498294047), (-2.9580326840985527, 3.7643270443876307), (1.386329658425102, 2.257406939128575), (2.7400239474420385, 1.761074868609728), (0.15516158876843011, 1.8733391795505279), (-3.9930310205657316, 1.6222416720845465), (2.0472211001584215, 2.7987759442558153), (0.9895675573536931, 1.7189654506227898), (2.3848795117394337, 2.38845062610726), (-3.260020149196059, 3.3875599838914), (2.6440365526564324, 1.7329666993431754), (0.26702035875428276, 1.7834571436551692), (4.82085242892304, 6.058595468039516), (4.655277361950496, 5.06399795105369), (-4.999867685984929, -2.9998686804270696), (2.719921940372031, 1.7767426852501316), (-1.409343122653619, 3.8405124790472454), (-2.09454917467672, 4.378849606098754), (-3.1875616867957213, 3.3981409068633988), (0.6046609108879144, 1.488163632630773), (3.4750976145314247, 1.3083442705041717), (4.894874721503832, 6.3359958818673405), (-4.902061382938973, -2.4312614429698693), (2.1841905451520027, 2.6183775995859215), (0.5607480533321834, 1.4949560214282391), (1.9524929913362374, 2.8607552122046713), (1.7325934203066486, 2.8479394643275953), (-1.6931021808394187, 3.9892233499654317), (1.790912681464519, 2.7397567963430896), (-0.8871236414235497, 3.273256253370202), (-1.5406732838146633, 4.046388599376793), (4.4296852553053245, 3.8630464289983992), (2.3485071200023278, 2.385940462227367), (-2.5521232439759123, 4.184316679547759), (4.402455984923449, 3.870472409283536), (-4.4594323838984, -0.17860682270451878), (-4.353387533137804, 0.35941247040266355), (-1.3755652557637732, 3.7940322820310377), (-4.205701568521184, 0.7032688165216282), (-3.93805777315013, 1.7580622066700806), (-4.058716302099706, 1.4385497270726546), (4.053611253103558, 2.6699151116470405), (-2.712946164356098, 3.97647899049007), (4.237486603028437, 3.3733306412669006), (-2.9013828997719715, 3.966640861649674), (0.06728183589404058, 1.992932344247335), (-2.0290134471901644, 4.13035271596 ...

# %% [markdown]
# **Test**

# %%
listCV_loss=[]
min_loss=100
n_best_split=0
net.eval() # Evaluation mode (e.g. disable dropout)
for i in range(n_split):
  #load the weights of the network i
  net = Net(Ni, Nh1, Nh2, No) 
  n=i+1
  net_state_dict = torch.load('/content/net_parameters.torch %d' %n)
  net.load_state_dict(net_state_dict)
  net=net.to(device)
  all_inputs = []
  all_outputs = []
  all_labels = []
  with torch.no_grad(): # Disable gradient tracking
    for sample_batched in test_loader:
      # Move data to device
      x_batch = sample_batched[0].to(device)
      label_batch = sample_batched[1].to(device)
      # Forward pass
      out = net(x_batch)
      # Save outputs and labels
      all_inputs.append(x_batch)
      all_outputs.append(out)
      all_labels.append(label_batch)
  # Concatenate all the outputs and labels in a single tensor
  all_inputs  = torch.cat(all_inputs)
  all_outputs = torch.cat(all_outputs)
  all_labels  = torch.cat(all_labels)
  
  test_loss = loss_fn(all_outputs, all_labels)
  if (test_loss < min_loss):
    min_loss=test_loss
    n_best_split=i
  listCV_loss.append(test_loss)
  print('### MODEL %d ####' %(i))
  print(f"AVERAGE TEST LOSS: {test_loss}")
# Out:
# Network initialized
# ### MODEL 0 ####
# AVERAGE TEST LOSS: 0.20464715361595154
# Network initialized
# ### MODEL 1 ####
# AVERAGE TEST LOSS: 0.26183021068573
# Network initialized
# ### MODEL 2 ####
# AVERAGE TEST LOSS: 0.12449510395526886

# %% [markdown]
# ### **Regression + Cross validation + Grid search**

# %%
#random permutation of the training set
torch_tensor_x = torch.tensor(train_df['input'].values)
torch_tensor_y = torch.tensor(train_df['label'].values)
permutation = np.random.permutation(100)
x_train = torch_tensor_x[permutation]
y_train = torch_tensor_y[permutation]
#Defining gridsearch space
Space=[(64,128,0.001),(128,256,0.001),(64,128,0.01),(128,256,0.01)]
Models_train_loss=[]
Models_val_loss=[]

for x in Space:
  #Initializing the network
  Ni = 1
  Nh1 = x[0]
  Nh2 = x[1]
  No = 1
  net = Net(Ni, Nh1, Nh2, No)
  net.to(device)

  # Define the loss function
  loss_fn = nn.MSELoss()

  # Define the optimizer
  lr=x[2]
  optimizer = optim.Adam(net.parameters(), lr=lr)
  kf = KFold(n_splits=n_split)

  #Defining parameters
  batch_size=16
  n_split=3
  num_epochs = 3000
  train_loss_log = []
  val_loss_log = []
  train_loss_fold=[]
  val_loss_fold=[]
  
  i=0
  for train_index, val_index in kf.split(x_train, y_train):  
    i+=1
    net.reset_weights()
    print('Fold number %d' %(i))
    x_train_fold = x_train[train_index] 
    y_train_fold = y_train[train_index] 
    x_val_fold = x_train[val_index] 
    y_val_fold = y_train[val_index] 
    #print(x_train_fold)
    #print(x_val_fold)
    #so now x_train_fold,y_train_fold contain the training set as a torch tensor and x_val_fold, y_val_fold contain the validation set as tensor.

    #DataLoader
    train = torch.utils.data.TensorDataset(x_train_fold, y_train_fold)
    val = torch.utils.data.TensorDataset(x_val_fold, y_val_fold)
    train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = False,num_workers=0)
    val_loader = torch.utils.data.DataLoader(val, batch_size = len(val), shuffle =False ,num_workers=0)
    #start the training
    for epoch_num in range(num_epochs):
        print('#################')
        print(f'# EPOCH {epoch_num} ')
        print(f'#FOLD {i}')
        print('#################')

        ### TRAIN
        train_loss= []
        net.train() # Training mode (e.g. enable dropout)
        for batch_index, (xx_batch, y_batch) in enumerate(train_loader):
          # Move data to device
          x_batch = xx_batch.to(device)
          label_batch = y_batch.to(device)
          x_batch=torch.unsqueeze(x_batch, 1)
          label_batch= torch.unsqueeze(label_batch, 1)

          # Forward pass
          x_batch = x_batch.view(x_batch.size(0), -1)
          out = net(x_batch.float())

          # Compute loss
          
          loss = loss_fn(out, label_batch.float())
          loss=loss

          # Backpropagation
          net.zero_grad()
          loss.backward()

          # Update the weights
          optimizer.step()

          # Save train loss for this batch
          loss_batch = loss.detach().cpu().numpy()
          train_loss.append(loss_batch)

        # Save average train loss
        train_loss = np.mean(train_loss)
        print(f"AVERAGE TRAIN LOSS: {train_loss}")

        ### VALIDATION
        val_loss= []
        net.eval() # Evaluation mode (e.g. disable dropout)
        with torch.no_grad(): # Disable gradient tracking
          for batch_index, (xx_batch, y_batch) in enumerate(val_loader):
            # Move data to device
            x_batch = xx_batch.to(device)
            label_batch = y_batch.to(device)
            x_batch=torch.unsqueeze(x_batch, 1)
            label_batch= torch.unsqueeze(label_batch, 1)

            # Forward pass
            x_batch = x_batch.view(x_batch.size(0), -1)
            out = net(x_batch.float())

            # Compute loss
            loss = loss_fn(out, label_batch.float())

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)

          # Save average validation loss
          val_loss = np.mean(val_loss)
          print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
    #save losses
    train_loss_log.append(train_loss)
    val_loss_log.append(val_loss)
    ### Save network parameters after each fold
    net_state_dict = net.state_dict()
    # Save the state dict to a file
    torch.save(net_state_dict, "net_parametersFold {} Space {}".format(i, x))
  Models_train_loss.append(np.mean(train_loss_log))
  Models_val_loss.append(np.mean(val_loss_log))
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# AVERAGE TRAIN LOSS: 0.3003598749637604
# AVERAGE VAL LOSS: 0.3016986846923828
# #################
# # EPOCH 2167
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24898095428943634
# AVERAGE VAL LOSS: 0.32787057757377625
# #################
# # EPOCH 2168
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30033841729164124
# AVERAGE VAL LOSS: 0.3017030954360962
# #################
# # EPOCH 2169
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24896535277366638
# AVERAGE VAL LOSS: 0.3278673589229584
# #################
# # EPOCH 2170
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.3003167510032654
# AVERAGE VAL LOSS: 0.3017078638076782
# #################
# # EPOCH 2171
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24894952774047852
# AVERAGE VAL LOSS: 0.3278641402721405
# #################
# # EPOCH 2172
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30029481649398804
# AVERAGE VAL LOSS: 0.3017124533653259
# #################
# # EPOCH 2173
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2489338368177414
# AVERAGE VAL LOSS: 0.32786065340042114
# #################
# # EPOCH 2174
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30027252435684204
# AVERAGE VAL LOSS: 0.30171725153923035
# #################
# # EPOCH 2175
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24891889095306396
# AVERAGE VAL LOSS: 0.3278569281101227
# #################
# # EPOCH 2176
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30025023221969604
# AVERAGE VAL LOSS: 0.3017221987247467
# #################
# # EPOCH 2177
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24890320003032684
# AVERAGE VAL LOSS: 0.3278532326221466
# #################
# # EPOCH 2178
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.3002285361289978
# AVERAGE VAL LOSS: 0.3017268478870392
# #################
# # EPOCH 2179
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24888785183429718
# AVERAGE VAL LOSS: 0.32785022258758545
# #################
# # EPOCH 2180
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30020713806152344
# AVERAGE VAL LOSS: 0.30173152685165405
# #################
# # EPOCH 2181
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2488723248243332
# AVERAGE VAL LOSS: 0.32784706354141235
# #################
# # EPOCH 2182
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30018556118011475
# AVERAGE VAL LOSS: 0.30173638463020325
# #################
# # EPOCH 2183
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24885663390159607
# AVERAGE VAL LOSS: 0.32784417271614075
# #################
# # EPOCH 2184
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30016428232192993
# AVERAGE VAL LOSS: 0.30174145102500916
# #################
# # EPOCH 2185
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2488415688276291
# AVERAGE VAL LOSS: 0.32784104347229004
# #################
# # EPOCH 2186
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.300142377614975
# AVERAGE VAL LOSS: 0.3017463684082031
# #################
# # EPOCH 2187
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24882614612579346
# AVERAGE VAL LOSS: 0.32783839106559753
# #################
# # EPOCH 2188
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.3001213073730469
# AVERAGE VAL LOSS: 0.3017512857913971
# #################
# # EPOCH 2189
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24881085753440857
# AVERAGE VAL LOSS: 0.3278353810310364
# #################
# # EPOCH 2190
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30009925365448
# AVERAGE VAL LOSS: 0.30175626277923584
# #################
# # EPOCH 2191
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2487955540418625
# AVERAGE VAL LOSS: 0.3278321623802185
# #################
# # EPOCH 2192
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.30007773637771606
# AVERAGE VAL LOSS: 0.301761269569397
# #################
# # EPOCH 2193
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2487802952528
# AVERAGE VAL LOSS: 0.327828973531723
# #################
# # EPOCH 2194
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.3000558912754059
# AVERAGE VAL LOSS: 0.3017662465572357
# #################
# # EPOCH 2195
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24876514077186584
# AVERAGE VAL LOSS: 0.3278258442878723
# #################
# # EPOCH 2196
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.3000340163707733
# AVERAGE VAL LOSS: 0.30177128314971924
# #################
# # EPOCH 2197
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24875013530254364
# AVERAGE VAL LOSS: 0.3278227150440216
# #################
# # EPOCH 2198
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.3000123202800751
# AVERAGE VAL LOSS: 0.3017767071723938
# #################
# # EPOCH 2199
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24873526394367218
# AVERAGE VAL LOSS: 0.3278198540210724
# #################
# # EPOCH 2200
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2999909818172455
# AVERAGE VAL LOSS: 0.30178192257881165
# #################
# # EPOCH 2201
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24871985614299774
# AVERAGE VAL LOSS: 0.3278171718120575
# #################
# # EPOCH 2202
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2999703288078308
# AVERAGE VAL LOSS: 0.3017868995666504
# #################
# # EPOCH 2203
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24870488047599792
# AVERAGE VAL LOSS: 0.3278144299983978
# #################
# # EPOCH 2204
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29994863271713257
# AVERAGE VAL LOSS: 0.3017922043800354
# #################
# # EPOCH 2205
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2486896514892578
# AVERAGE VAL LOSS: 0.3278118073940277
# #################
# # EPOCH 2206
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29992666840553284
# AVERAGE VAL LOSS: 0.30179738998413086
# #################
# # EPOCH 2207
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24867482483386993
# AVERAGE VAL LOSS: 0.3278084099292755
# #################
# # EPOCH 2208
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29990455508232117
# AVERAGE VAL LOSS: 0.3018026649951935
# #################
# # EPOCH 2209
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24865980446338654
# AVERAGE VAL LOSS: 0.3278053402900696
# #################
# # EPOCH 2210
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29988256096839905
# AVERAGE VAL LOSS: 0.3018079698085785
# #################
# # EPOCH 2211
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24864503741264343
# AVERAGE VAL LOSS: 0.3278023898601532
# #################
# # EPOCH 2212
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2998611629009247
# AVERAGE VAL LOSS: 0.30181339383125305
# #################
# # EPOCH 2213
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24863021075725555
# AVERAGE VAL LOSS: 0.32779979705810547
# #################
# # EPOCH 2214
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29984012246131897
# AVERAGE VAL LOSS: 0.3018186390399933
# #################
# # EPOCH 2215
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24861502647399902
# AVERAGE VAL LOSS: 0.327797532081604
# #################
# # EPOCH 2216
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29981890320777893
# AVERAGE VAL LOSS: 0.30182400345802307
# #################
# # EPOCH 2217
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24860019981861115
# AVERAGE VAL LOSS: 0.3277946710586548
# #################
# # EPOCH 2218
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2997968792915344
# AVERAGE VAL LOSS: 0.3018293082714081
# #################
# # EPOCH 2219
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2485852688550949
# AVERAGE VAL LOSS: 0.32779133319854736
# #################
# # EPOCH 2220
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2997743487358093
# AVERAGE VAL LOSS: 0.3018348217010498
# #################
# # EPOCH 2221
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2485707700252533
# AVERAGE VAL LOSS: 0.32778799533843994
# #################
# # EPOCH 2222
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29975205659866333
# AVERAGE VAL LOSS: 0.3018403649330139
# #################
# # EPOCH 2223
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24855630099773407
# AVERAGE VAL LOSS: 0.32778504490852356
# #################
# # EPOCH 2224
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2997302711009979
# AVERAGE VAL LOSS: 0.30184611678123474
# #################
# # EPOCH 2225
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24854150414466858
# AVERAGE VAL LOSS: 0.32778260111808777
# #################
# # EPOCH 2226
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2997089922428131
# AVERAGE VAL LOSS: 0.30185171961784363
# #################
# # EPOCH 2227
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24852688610553741
# AVERAGE VAL LOSS: 0.3277803659439087
# #################
# # EPOCH 2228
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2996879816055298
# AVERAGE VAL LOSS: 0.3018571138381958
# #################
# # EPOCH 2229
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24851182103157043
# AVERAGE VAL LOSS: 0.32777753472328186
# #################
# # EPOCH 2230
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2996665835380554
# AVERAGE VAL LOSS: 0.3018627464771271
# #################
# # EPOCH 2231
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24849705398082733
# AVERAGE VAL LOSS: 0.3277750313282013
# #################
# # EPOCH 2232
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2996442914009094
# AVERAGE VAL LOSS: 0.3018683195114136
# #################
# # EPOCH 2233
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24848246574401855
# AVERAGE VAL LOSS: 0.3277718722820282
# #################
# # EPOCH 2234
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2996222972869873
# AVERAGE VAL LOSS: 0.3018742501735687
# #################
# # EPOCH 2235
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24846820533275604
# AVERAGE VAL LOSS: 0.3277694582939148
# #################
# # EPOCH 2236
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29960110783576965
# AVERAGE VAL LOSS: 0.30187997221946716
# #################
# # EPOCH 2237
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24845388531684875
# AVERAGE VAL LOSS: 0.3277670741081238
# #################
# # EPOCH 2238
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29957959055900574
# AVERAGE VAL LOSS: 0.3018856644630432
# #################
# # EPOCH 2239
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24843904376029968
# AVERAGE VAL LOSS: 0.32776498794555664
# #################
# # EPOCH 2240
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29955893754959106
# AVERAGE VAL LOSS: 0.30189114809036255
# #################
# # EPOCH 2241
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24842426180839539
# AVERAGE VAL LOSS: 0.3277621567249298
# #################
# # EPOCH 2242
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2995362877845764
# AVERAGE VAL LOSS: 0.30189692974090576
# #################
# # EPOCH 2243
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24841034412384033
# AVERAGE VAL LOSS: 0.32775944471359253
# #################
# # EPOCH 2244
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2995144724845886
# AVERAGE VAL LOSS: 0.3019029498100281
# #################
# # EPOCH 2245
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2483961135149002
# AVERAGE VAL LOSS: 0.3277569115161896
# #################
# # EPOCH 2246
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29949337244033813
# AVERAGE VAL LOSS: 0.30190879106521606
# #################
# # EPOCH 2247
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24838168919086456
# AVERAGE VAL LOSS: 0.32775458693504333
# #################
# # EPOCH 2248
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2994721531867981
# AVERAGE VAL LOSS: 0.30191487073898315
# #################
# # EPOCH 2249
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24836719036102295
# AVERAGE VAL LOSS: 0.3277527391910553
# #################
# # EPOCH 2250
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29945099353790283
# AVERAGE VAL LOSS: 0.30192071199417114
# #################
# # EPOCH 2251
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24835245311260223
# AVERAGE VAL LOSS: 0.3277505934238434
# #################
# # EPOCH 2252
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2994294762611389
# AVERAGE VAL LOSS: 0.30192676186561584
# #################
# # EPOCH 2253
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24833813309669495
# AVERAGE VAL LOSS: 0.3277479410171509
# #################
# # EPOCH 2254
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29940757155418396
# AVERAGE VAL LOSS: 0.30193302035331726
# #################
# # EPOCH 2255
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2483241856098175
# AVERAGE VAL LOSS: 0.3277456760406494
# #################
# # EPOCH 2256
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29938557744026184
# AVERAGE VAL LOSS: 0.3019389510154724
# #################
# # EPOCH 2257
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24831004440784454
# AVERAGE VAL LOSS: 0.32774272561073303
# #################
# # EPOCH 2258
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29936355352401733
# AVERAGE VAL LOSS: 0.30194514989852905
# #################
# # EPOCH 2259
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2482958734035492
# AVERAGE VAL LOSS: 0.32774069905281067
# #################
# # EPOCH 2260
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29934200644493103
# AVERAGE VAL LOSS: 0.3019513785839081
# #################
# # EPOCH 2261
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24828176200389862
# AVERAGE VAL LOSS: 0.32773885130882263
# #################
# # EPOCH 2262
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29932084679603577
# AVERAGE VAL LOSS: 0.30195745825767517
# #################
# # EPOCH 2263
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24826745688915253
# AVERAGE VAL LOSS: 0.3277367353439331
# #################
# # EPOCH 2264
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2992996573448181
# AVERAGE VAL LOSS: 0.3019636273384094
# #################
# # EPOCH 2265
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24825334548950195
# AVERAGE VAL LOSS: 0.32773447036743164
# #################
# # EPOCH 2266
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2992780804634094
# AVERAGE VAL LOSS: 0.30196988582611084
# #################
# # EPOCH 2267
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24823911488056183
# AVERAGE VAL LOSS: 0.3277320861816406
# #################
# # EPOCH 2268
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2992568612098694
# AVERAGE VAL LOSS: 0.30197617411613464
# #################
# # EPOCH 2269
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24822497367858887
# AVERAGE VAL LOSS: 0.32773053646087646
# #################
# # EPOCH 2270
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29923540353775024
# AVERAGE VAL LOSS: 0.3019823729991913
# #################
# # EPOCH 2271
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24821117520332336
# AVERAGE VAL LOSS: 0.32772818207740784
# #################
# # EPOCH 2272
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29921382665634155
# AVERAGE VAL LOSS: 0.3019882142543793
# #################
# # EPOCH 2273
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24819695949554443
# AVERAGE VAL LOSS: 0.3277258574962616
# #################
# # EPOCH 2274
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29919177293777466
# AVERAGE VAL LOSS: 0.3019946217536926
# #################
# # EPOCH 2275
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2481829673051834
# AVERAGE VAL LOSS: 0.32772353291511536
# #################
# # EPOCH 2276
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29916948080062866
# AVERAGE VAL LOSS: 0.3020012676715851
# #################
# # EPOCH 2277
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24816937744617462
# AVERAGE VAL LOSS: 0.3277216851711273
# #################
# # EPOCH 2278
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29914847016334534
# AVERAGE VAL LOSS: 0.302007794380188
# #################
# # EPOCH 2279
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24815507233142853
# AVERAGE VAL LOSS: 0.3277195990085602
# #################
# # EPOCH 2280
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29912716150283813
# AVERAGE VAL LOSS: 0.3020142614841461
# #################
# # EPOCH 2281
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24814137816429138
# AVERAGE VAL LOSS: 0.3277176022529602
# #################
# # EPOCH 2282
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29910555481910706
# AVERAGE VAL LOSS: 0.3020205795764923
# #################
# # EPOCH 2283
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2481270134449005
# AVERAGE VAL LOSS: 0.3277159631252289
# #################
# # EPOCH 2284
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2990841269493103
# AVERAGE VAL LOSS: 0.3020274043083191
# #################
# # EPOCH 2285
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24811331927776337
# AVERAGE VAL LOSS: 0.32771360874176025
# #################
# # EPOCH 2286
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2990620732307434
# AVERAGE VAL LOSS: 0.30203351378440857
# #################
# # EPOCH 2287
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24809959530830383
# AVERAGE VAL LOSS: 0.32771170139312744
# #################
# # EPOCH 2288
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29904046654701233
# AVERAGE VAL LOSS: 0.3020404577255249
# #################
# # EPOCH 2289
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2480861246585846
# AVERAGE VAL LOSS: 0.32770949602127075
# #################
# # EPOCH 2290
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2990189492702484
# AVERAGE VAL LOSS: 0.30204668641090393
# #################
# # EPOCH 2291
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24807219207286835
# AVERAGE VAL LOSS: 0.32770779728889465
# #################
# # EPOCH 2292
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2989978790283203
# AVERAGE VAL LOSS: 0.30205363035202026
# #################
# # EPOCH 2293
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2480582743883133
# AVERAGE VAL LOSS: 0.32770636677742004
# #################
# # EPOCH 2294
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2989763021469116
# AVERAGE VAL LOSS: 0.30206021666526794
# #################
# # EPOCH 2295
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24804475903511047
# AVERAGE VAL LOSS: 0.3277043402194977
# #################
# # EPOCH 2296
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29895445704460144
# AVERAGE VAL LOSS: 0.3020668625831604
# #################
# # EPOCH 2297
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24803128838539124
# AVERAGE VAL LOSS: 0.3277021646499634
# #################
# # EPOCH 2298
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29893264174461365
# AVERAGE VAL LOSS: 0.30207350850105286
# #################
# # EPOCH 2299
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24801750481128693
# AVERAGE VAL LOSS: 0.327700138092041
# #################
# # EPOCH 2300
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29891103506088257
# AVERAGE VAL LOSS: 0.30208057165145874
# #################
# # EPOCH 2301
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24800410866737366
# AVERAGE VAL LOSS: 0.32769840955734253
# #################
# # EPOCH 2302
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2988893985748291
# AVERAGE VAL LOSS: 0.30208727717399597
# #################
# # EPOCH 2303
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24799063801765442
# AVERAGE VAL LOSS: 0.32769688963890076
# #################
# # EPOCH 2304
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29886800050735474
# AVERAGE VAL LOSS: 0.30209410190582275
# #################
# # EPOCH 2305
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2479768991470337
# AVERAGE VAL LOSS: 0.32769477367401123
# #################
# # EPOCH 2306
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29884570837020874
# AVERAGE VAL LOSS: 0.3021009564399719
# #################
# # EPOCH 2307
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24796335399150848
# AVERAGE VAL LOSS: 0.32769301533699036
# #################
# # EPOCH 2308
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2988237738609314
# AVERAGE VAL LOSS: 0.30210813879966736
# #################
# # EPOCH 2309
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2479502260684967
# AVERAGE VAL LOSS: 0.3276911675930023
# #################
# # EPOCH 2310
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2988026738166809
# AVERAGE VAL LOSS: 0.3021150529384613
# #################
# # EPOCH 2311
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2479363977909088
# AVERAGE VAL LOSS: 0.32768961787223816
# #################
# # EPOCH 2312
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2987815737724304
# AVERAGE VAL LOSS: 0.30212199687957764
# #################
# # EPOCH 2313
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24792292714118958
# AVERAGE VAL LOSS: 0.327688068151474
# #################
# # EPOCH 2314
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.298759788274765
# AVERAGE VAL LOSS: 0.30212876200675964
# #################
# # EPOCH 2315
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24790947139263153
# AVERAGE VAL LOSS: 0.3276866674423218
# #################
# # EPOCH 2316
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29873836040496826
# AVERAGE VAL LOSS: 0.30213600397109985
# #################
# # EPOCH 2317
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24789603054523468
# AVERAGE VAL LOSS: 0.32768514752388
# #################
# # EPOCH 2318
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29871687293052673
# AVERAGE VAL LOSS: 0.3021428883075714
# #################
# # EPOCH 2319
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2478824406862259
# AVERAGE VAL LOSS: 0.3276834189891815
# #################
# # EPOCH 2320
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2986951768398285
# AVERAGE VAL LOSS: 0.302150160074234
# #################
# # EPOCH 2321
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2478693276643753
# AVERAGE VAL LOSS: 0.32768213748931885
# #################
# # EPOCH 2322
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2986738085746765
# AVERAGE VAL LOSS: 0.30215731263160706
# #################
# # EPOCH 2323
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2478560507297516
# AVERAGE VAL LOSS: 0.327680379152298
# #################
# # EPOCH 2324
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29865211248397827
# AVERAGE VAL LOSS: 0.30216458439826965
# #################
# # EPOCH 2325
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24784255027770996
# AVERAGE VAL LOSS: 0.3276791572570801
# #################
# # EPOCH 2326
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29863104224205017
# AVERAGE VAL LOSS: 0.30217158794403076
# #################
# # EPOCH 2327
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24782919883728027
# AVERAGE VAL LOSS: 0.3276771605014801
# #################
# # EPOCH 2328
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29860860109329224
# AVERAGE VAL LOSS: 0.3021789491176605
# #################
# # EPOCH 2329
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24781623482704163
# AVERAGE VAL LOSS: 0.3276759684085846
# #################
# # EPOCH 2330
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29858723282814026
# AVERAGE VAL LOSS: 0.3021862804889679
# #################
# # EPOCH 2331
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2478034496307373
# AVERAGE VAL LOSS: 0.3276745676994324
# #################
# # EPOCH 2332
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29856613278388977
# AVERAGE VAL LOSS: 0.30219346284866333
# #################
# # EPOCH 2333
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2477899044752121
# AVERAGE VAL LOSS: 0.32767289876937866
# #################
# # EPOCH 2334
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29854458570480347
# AVERAGE VAL LOSS: 0.3022007942199707
# #################
# # EPOCH 2335
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2477767914533615
# AVERAGE VAL LOSS: 0.3276722729206085
# #################
# # EPOCH 2336
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29852375388145447
# AVERAGE VAL LOSS: 0.3022080659866333
# #################
# # EPOCH 2337
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24776344001293182
# AVERAGE VAL LOSS: 0.3276715874671936
# #################
# # EPOCH 2338
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29850247502326965
# AVERAGE VAL LOSS: 0.3022156357765198
# #################
# # EPOCH 2339
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2477504312992096
# AVERAGE VAL LOSS: 0.3276694715023041
# #################
# # EPOCH 2340
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29848015308380127
# AVERAGE VAL LOSS: 0.30222287774086
# #################
# # EPOCH 2341
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24773743748664856
# AVERAGE VAL LOSS: 0.3276682198047638
# #################
# # EPOCH 2342
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29845839738845825
# AVERAGE VAL LOSS: 0.30223044753074646
# #################
# # EPOCH 2343
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24772438406944275
# AVERAGE VAL LOSS: 0.32766708731651306
# #################
# # EPOCH 2344
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2984371781349182
# AVERAGE VAL LOSS: 0.30223792791366577
# #################
# # EPOCH 2345
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24771150946617126
# AVERAGE VAL LOSS: 0.3276655077934265
# #################
# # EPOCH 2346
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2984153628349304
# AVERAGE VAL LOSS: 0.3022453784942627
# #################
# # EPOCH 2347
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24769821763038635
# AVERAGE VAL LOSS: 0.3276643455028534
# #################
# # EPOCH 2348
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29839375615119934
# AVERAGE VAL LOSS: 0.30225300788879395
# #################
# # EPOCH 2349
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24768562614917755
# AVERAGE VAL LOSS: 0.32766270637512207
# #################
# # EPOCH 2350
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.298371821641922
# AVERAGE VAL LOSS: 0.3022604286670685
# #################
# # EPOCH 2351
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2476726770401001
# AVERAGE VAL LOSS: 0.32766157388687134
# #################
# # EPOCH 2352
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29835039377212524
# AVERAGE VAL LOSS: 0.30226829648017883
# #################
# # EPOCH 2353
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24765965342521667
# AVERAGE VAL LOSS: 0.32766085863113403
# #################
# # EPOCH 2354
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2983291745185852
# AVERAGE VAL LOSS: 0.30227598547935486
# #################
# # EPOCH 2355
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.247646763920784
# AVERAGE VAL LOSS: 0.32765987515449524
# #################
# # EPOCH 2356
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2983078360557556
# AVERAGE VAL LOSS: 0.30228349566459656
# #################
# # EPOCH 2357
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24763374030590057
# AVERAGE VAL LOSS: 0.32765889167785645
# #################
# # EPOCH 2358
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.298286110162735
# AVERAGE VAL LOSS: 0.3022913932800293
# #################
# # EPOCH 2359
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24762091040611267
# AVERAGE VAL LOSS: 0.3276573717594147
# #################
# # EPOCH 2360
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29826363921165466
# AVERAGE VAL LOSS: 0.3022991120815277
# #################
# # EPOCH 2361
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2476082593202591
# AVERAGE VAL LOSS: 0.3276563286781311
# #################
# # EPOCH 2362
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29824212193489075
# AVERAGE VAL LOSS: 0.30230712890625
# #################
# # EPOCH 2363
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24759559333324432
# AVERAGE VAL LOSS: 0.3276548683643341
# #################
# # EPOCH 2364
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2982207238674164
# AVERAGE VAL LOSS: 0.302314817905426
# #################
# # EPOCH 2365
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24758294224739075
# AVERAGE VAL LOSS: 0.32765454053878784
# #################
# # EPOCH 2366
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29819926619529724
# AVERAGE VAL LOSS: 0.30232250690460205
# #################
# # EPOCH 2367
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2475700080394745
# AVERAGE VAL LOSS: 0.32765325903892517
# #################
# # EPOCH 2368
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29817724227905273
# AVERAGE VAL LOSS: 0.3023304343223572
# #################
# # EPOCH 2369
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24755719304084778
# AVERAGE VAL LOSS: 0.3276521563529968
# #################
# # EPOCH 2370
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29815539717674255
# AVERAGE VAL LOSS: 0.30233851075172424
# #################
# # EPOCH 2371
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24754473567008972
# AVERAGE VAL LOSS: 0.32765114307403564
# #################
# # EPOCH 2372
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29813331365585327
# AVERAGE VAL LOSS: 0.302346795797348
# #################
# # EPOCH 2373
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24753227829933167
# AVERAGE VAL LOSS: 0.3276499807834625
# #################
# # EPOCH 2374
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2981119751930237
# AVERAGE VAL LOSS: 0.30235475301742554
# #################
# # EPOCH 2375
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24751965701580048
# AVERAGE VAL LOSS: 0.32764968276023865
# #################
# # EPOCH 2376
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29809096455574036
# AVERAGE VAL LOSS: 0.30236247181892395
# #################
# # EPOCH 2377
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24750664830207825
# AVERAGE VAL LOSS: 0.32764893770217896
# #################
# # EPOCH 2378
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29806920886039734
# AVERAGE VAL LOSS: 0.30237066745758057
# #################
# # EPOCH 2379
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24749413132667542
# AVERAGE VAL LOSS: 0.3276475965976715
# #################
# # EPOCH 2380
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2980469763278961
# AVERAGE VAL LOSS: 0.30237871408462524
# #################
# # EPOCH 2381
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24748162925243378
# AVERAGE VAL LOSS: 0.3276468515396118
# #################
# # EPOCH 2382
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2980249524116516
# AVERAGE VAL LOSS: 0.3023870289325714
# #################
# # EPOCH 2383
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2474694699048996
# AVERAGE VAL LOSS: 0.32764557003974915
# #################
# # EPOCH 2384
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2980029284954071
# AVERAGE VAL LOSS: 0.3023952543735504
# #################
# # EPOCH 2385
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2474568635225296
# AVERAGE VAL LOSS: 0.3276449143886566
# #################
# # EPOCH 2386
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29798173904418945
# AVERAGE VAL LOSS: 0.30240342020988464
# #################
# # EPOCH 2387
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24744442105293274
# AVERAGE VAL LOSS: 0.3276446759700775
# #################
# # EPOCH 2388
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29796046018600464
# AVERAGE VAL LOSS: 0.30241161584854126
# #################
# # EPOCH 2389
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.247432142496109
# AVERAGE VAL LOSS: 0.3276435136795044
# #################
# # EPOCH 2390
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2979383170604706
# AVERAGE VAL LOSS: 0.30241960287094116
# #################
# # EPOCH 2391
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24741986393928528
# AVERAGE VAL LOSS: 0.3276427686214447
# #################
# # EPOCH 2392
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2979164719581604
# AVERAGE VAL LOSS: 0.30242806673049927
# #################
# # EPOCH 2393
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2474076747894287
# AVERAGE VAL LOSS: 0.32764187455177307
# #################
# # EPOCH 2394
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29789456725120544
# AVERAGE VAL LOSS: 0.30243656039237976
# #################
# # EPOCH 2395
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24739547073841095
# AVERAGE VAL LOSS: 0.32764124870300293
# #################
# # EPOCH 2396
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29787322878837585
# AVERAGE VAL LOSS: 0.3024449348449707
# #################
# # EPOCH 2397
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24738287925720215
# AVERAGE VAL LOSS: 0.3276403844356537
# #################
# # EPOCH 2398
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2978512942790985
# AVERAGE VAL LOSS: 0.3024529814720154
# #################
# # EPOCH 2399
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24737048149108887
# AVERAGE VAL LOSS: 0.3276396095752716
# #################
# # EPOCH 2400
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29782891273498535
# AVERAGE VAL LOSS: 0.30246132612228394
# #################
# # EPOCH 2401
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24735823273658752
# AVERAGE VAL LOSS: 0.32763877511024475
# #################
# # EPOCH 2402
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.297806978225708
# AVERAGE VAL LOSS: 0.30246996879577637
# #################
# # EPOCH 2403
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24734608829021454
# AVERAGE VAL LOSS: 0.327638179063797
# #################
# # EPOCH 2404
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2977852523326874
# AVERAGE VAL LOSS: 0.3024786412715912
# #################
# # EPOCH 2405
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2473340481519699
# AVERAGE VAL LOSS: 0.3276377022266388
# #################
# # EPOCH 2406
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2977637052536011
# AVERAGE VAL LOSS: 0.3024871349334717
# #################
# # EPOCH 2407
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2473219633102417
# AVERAGE VAL LOSS: 0.327637255191803
# #################
# # EPOCH 2408
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2977423071861267
# AVERAGE VAL LOSS: 0.30249565839767456
# #################
# # EPOCH 2409
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24730940163135529
# AVERAGE VAL LOSS: 0.32763659954071045
# #################
# # EPOCH 2410
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29771989583969116
# AVERAGE VAL LOSS: 0.3025043308734894
# #################
# # EPOCH 2411
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24729767441749573
# AVERAGE VAL LOSS: 0.327635794878006
# #################
# # EPOCH 2412
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2976974546909332
# AVERAGE VAL LOSS: 0.3025127947330475
# #################
# # EPOCH 2413
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24728555977344513
# AVERAGE VAL LOSS: 0.3276353180408478
# #################
# # EPOCH 2414
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29767560958862305
# AVERAGE VAL LOSS: 0.3025214672088623
# #################
# # EPOCH 2415
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24727359414100647
# AVERAGE VAL LOSS: 0.32763466238975525
# #################
# # EPOCH 2416
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2976536750793457
# AVERAGE VAL LOSS: 0.3025299608707428
# #################
# # EPOCH 2417
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24726161360740662
# AVERAGE VAL LOSS: 0.32763388752937317
# #################
# # EPOCH 2418
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2976314127445221
# AVERAGE VAL LOSS: 0.30253860354423523
# #################
# # EPOCH 2419
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2472495585680008
# AVERAGE VAL LOSS: 0.3276333510875702
# #################
# # EPOCH 2420
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29760876297950745
# AVERAGE VAL LOSS: 0.3025473654270172
# #################
# # EPOCH 2421
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2472376525402069
# AVERAGE VAL LOSS: 0.32763221859931946
# #################
# # EPOCH 2422
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29758596420288086
# AVERAGE VAL LOSS: 0.3025563061237335
# #################
# # EPOCH 2423
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24722592532634735
# AVERAGE VAL LOSS: 0.32763123512268066
# #################
# # EPOCH 2424
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2975630760192871
# AVERAGE VAL LOSS: 0.30256515741348267
# #################
# # EPOCH 2425
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2472141534090042
# AVERAGE VAL LOSS: 0.327629953622818
# #################
# # EPOCH 2426
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2975403368473053
# AVERAGE VAL LOSS: 0.3025740683078766
# #################
# # EPOCH 2427
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2472023218870163
# AVERAGE VAL LOSS: 0.3276294469833374
# #################
# # EPOCH 2428
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29751768708229065
# AVERAGE VAL LOSS: 0.3025829493999481
# #################
# # EPOCH 2429
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24719080328941345
# AVERAGE VAL LOSS: 0.3276287615299225
# #################
# # EPOCH 2430
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2974953353404999
# AVERAGE VAL LOSS: 0.30259180068969727
# #################
# # EPOCH 2431
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2471790760755539
# AVERAGE VAL LOSS: 0.32762810587882996
# #################
# # EPOCH 2432
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29747262597084045
# AVERAGE VAL LOSS: 0.3026006817817688
# #################
# # EPOCH 2433
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24716754257678986
# AVERAGE VAL LOSS: 0.3276270925998688
# #################
# # EPOCH 2434
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2974499762058258
# AVERAGE VAL LOSS: 0.3026096224784851
# #################
# # EPOCH 2435
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2471562623977661
# AVERAGE VAL LOSS: 0.3276260793209076
# #################
# # EPOCH 2436
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2974265217781067
# AVERAGE VAL LOSS: 0.30261844396591187
# #################
# # EPOCH 2437
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2471446990966797
# AVERAGE VAL LOSS: 0.32762521505355835
# #################
# # EPOCH 2438
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2974033057689667
# AVERAGE VAL LOSS: 0.3026273846626282
# #################
# # EPOCH 2439
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24713322520256042
# AVERAGE VAL LOSS: 0.32762396335601807
# #################
# # EPOCH 2440
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2973795533180237
# AVERAGE VAL LOSS: 0.30263641476631165
# #################
# # EPOCH 2441
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.247122123837471
# AVERAGE VAL LOSS: 0.3276223838329315
# #################
# # EPOCH 2442
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29735490679740906
# AVERAGE VAL LOSS: 0.3026452958583832
# #################
# # EPOCH 2443
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24711088836193085
# AVERAGE VAL LOSS: 0.32762089371681213
# #################
# # EPOCH 2444
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29733046889305115
# AVERAGE VAL LOSS: 0.30265435576438904
# #################
# # EPOCH 2445
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24710015952587128
# AVERAGE VAL LOSS: 0.32761886715888977
# #################
# # EPOCH 2446
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29730573296546936
# AVERAGE VAL LOSS: 0.3026636242866516
# #################
# # EPOCH 2447
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24708974361419678
# AVERAGE VAL LOSS: 0.32761695981025696
# #################
# # EPOCH 2448
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29728013277053833
# AVERAGE VAL LOSS: 0.30267253518104553
# #################
# # EPOCH 2449
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2470790445804596
# AVERAGE VAL LOSS: 0.3276144862174988
# #################
# # EPOCH 2450
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29725381731987
# AVERAGE VAL LOSS: 0.30268171429634094
# #################
# # EPOCH 2451
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24706867337226868
# AVERAGE VAL LOSS: 0.3276109993457794
# #################
# # EPOCH 2452
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2972254157066345
# AVERAGE VAL LOSS: 0.30269038677215576
# #################
# # EPOCH 2453
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24705906212329865
# AVERAGE VAL LOSS: 0.32760679721832275
# #################
# # EPOCH 2454
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2971958816051483
# AVERAGE VAL LOSS: 0.3026994466781616
# #################
# # EPOCH 2455
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24705009162425995
# AVERAGE VAL LOSS: 0.3276016414165497
# #################
# # EPOCH 2456
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2971648573875427
# AVERAGE VAL LOSS: 0.3027084469795227
# #################
# # EPOCH 2457
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24704141914844513
# AVERAGE VAL LOSS: 0.3275957405567169
# #################
# # EPOCH 2458
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29713159799575806
# AVERAGE VAL LOSS: 0.3027172088623047
# #################
# # EPOCH 2459
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24703356623649597
# AVERAGE VAL LOSS: 0.32758772373199463
# #################
# # EPOCH 2460
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2970939874649048
# AVERAGE VAL LOSS: 0.30272579193115234
# #################
# # EPOCH 2461
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2470276802778244
# AVERAGE VAL LOSS: 0.32757726311683655
# #################
# # EPOCH 2462
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2970510423183441
# AVERAGE VAL LOSS: 0.3027341961860657
# #################
# # EPOCH 2463
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24702385067939758
# AVERAGE VAL LOSS: 0.3275621235370636
# #################
# # EPOCH 2464
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2969985604286194
# AVERAGE VAL LOSS: 0.30274203419685364
# #################
# # EPOCH 2465
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24702413380146027
# AVERAGE VAL LOSS: 0.3275406062602997
# #################
# # EPOCH 2466
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2969314455986023
# AVERAGE VAL LOSS: 0.30274924635887146
# #################
# # EPOCH 2467
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24703189730644226
# AVERAGE VAL LOSS: 0.3275076150894165
# #################
# # EPOCH 2468
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2968401312828064
# AVERAGE VAL LOSS: 0.3027544915676117
# #################
# # EPOCH 2469
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.247052401304245
# AVERAGE VAL LOSS: 0.32745328545570374
# #################
# # EPOCH 2470
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29670247435569763
# AVERAGE VAL LOSS: 0.30275556445121765
# #################
# # EPOCH 2471
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.247097447514534
# AVERAGE VAL LOSS: 0.3273567259311676
# #################
# # EPOCH 2472
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2964819371700287
# AVERAGE VAL LOSS: 0.3027476668357849
# #################
# # EPOCH 2473
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2471810132265091
# AVERAGE VAL LOSS: 0.32718515396118164
# #################
# # EPOCH 2474
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2961328327655792
# AVERAGE VAL LOSS: 0.3027338683605194
# #################
# # EPOCH 2475
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24730615317821503
# AVERAGE VAL LOSS: 0.3269306421279907
# #################
# # EPOCH 2476
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2956586480140686
# AVERAGE VAL LOSS: 0.3027353584766388
# #################
# # EPOCH 2477
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24745135009288788
# AVERAGE VAL LOSS: 0.32663294672966003
# #################
# # EPOCH 2478
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29514080286026
# AVERAGE VAL LOSS: 0.30275583267211914
# #################
# # EPOCH 2479
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24759121239185333
# AVERAGE VAL LOSS: 0.3263411223888397
# #################
# # EPOCH 2480
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29467126727104187
# AVERAGE VAL LOSS: 0.30278149247169495
# #################
# # EPOCH 2481
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24770286679267883
# AVERAGE VAL LOSS: 0.32608917355537415
# #################
# # EPOCH 2482
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29429352283477783
# AVERAGE VAL LOSS: 0.30280014872550964
# #################
# # EPOCH 2483
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24777765572071075
# AVERAGE VAL LOSS: 0.3258899748325348
# #################
# # EPOCH 2484
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2940056025981903
# AVERAGE VAL LOSS: 0.30280813574790955
# #################
# # EPOCH 2485
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24781906604766846
# AVERAGE VAL LOSS: 0.32573533058166504
# #################
# # EPOCH 2486
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2937808334827423
# AVERAGE VAL LOSS: 0.30281001329421997
# #################
# # EPOCH 2487
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24783968925476074
# AVERAGE VAL LOSS: 0.32561105489730835
# #################
# # EPOCH 2488
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.293599396944046
# AVERAGE VAL LOSS: 0.3028111457824707
# #################
# # EPOCH 2489
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24785175919532776
# AVERAGE VAL LOSS: 0.3255099654197693
# #################
# # EPOCH 2490
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2934580147266388
# AVERAGE VAL LOSS: 0.30281364917755127
# #################
# # EPOCH 2491
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2478598654270172
# AVERAGE VAL LOSS: 0.3254322111606598
# #################
# # EPOCH 2492
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29336029291152954
# AVERAGE VAL LOSS: 0.3028159439563751
# #################
# # EPOCH 2493
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24786241352558136
# AVERAGE VAL LOSS: 0.32538121938705444
# #################
# # EPOCH 2494
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2933053970336914
# AVERAGE VAL LOSS: 0.302815318107605
# #################
# # EPOCH 2495
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24785642325878143
# AVERAGE VAL LOSS: 0.3253525197505951
# #################
# # EPOCH 2496
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.293283611536026
# AVERAGE VAL LOSS: 0.3028120696544647
# #################
# # EPOCH 2497
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24784326553344727
# AVERAGE VAL LOSS: 0.325341135263443
# #################
# # EPOCH 2498
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29328423738479614
# AVERAGE VAL LOSS: 0.3028082549571991
# #################
# # EPOCH 2499
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2478269636631012
# AVERAGE VAL LOSS: 0.3253413438796997
# #################
# # EPOCH 2500
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29330024123191833
# AVERAGE VAL LOSS: 0.3028048872947693
# #################
# # EPOCH 2501
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24780964851379395
# AVERAGE VAL LOSS: 0.3253513276576996
# #################
# # EPOCH 2502
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2933312952518463
# AVERAGE VAL LOSS: 0.3028026521205902
# #################
# # EPOCH 2503
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24779145419597626
# AVERAGE VAL LOSS: 0.3253714442253113
# #################
# # EPOCH 2504
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29337742924690247
# AVERAGE VAL LOSS: 0.30280113220214844
# #################
# # EPOCH 2505
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24777063727378845
# AVERAGE VAL LOSS: 0.3254017233848572
# #################
# # EPOCH 2506
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.293434739112854
# AVERAGE VAL LOSS: 0.3028002977371216
# #################
# # EPOCH 2507
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2477470189332962
# AVERAGE VAL LOSS: 0.3254392147064209
# #################
# # EPOCH 2508
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2934955954551697
# AVERAGE VAL LOSS: 0.3028014898300171
# #################
# # EPOCH 2509
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24772119522094727
# AVERAGE VAL LOSS: 0.3254780173301697
# #################
# # EPOCH 2510
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2935464382171631
# AVERAGE VAL LOSS: 0.3028108775615692
# #################
# # EPOCH 2511
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24769148230552673
# AVERAGE VAL LOSS: 0.32549145817756653
# #################
# # EPOCH 2512
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2935303747653961
# AVERAGE VAL LOSS: 0.30285540223121643
# #################
# # EPOCH 2513
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24761386215686798
# AVERAGE VAL LOSS: 0.3253307342529297
# #################
# # EPOCH 2514
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29304593801498413
# AVERAGE VAL LOSS: 0.30290839076042175
# #################
# # EPOCH 2515
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24769730865955353
# AVERAGE VAL LOSS: 0.3252979815006256
# #################
# # EPOCH 2516
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2929822504520416
# AVERAGE VAL LOSS: 0.30293887853622437
# #################
# # EPOCH 2517
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24782642722129822
# AVERAGE VAL LOSS: 0.32529640197753906
# #################
# # EPOCH 2518
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29306042194366455
# AVERAGE VAL LOSS: 0.30293726921081543
# #################
# # EPOCH 2519
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24785594642162323
# AVERAGE VAL LOSS: 0.3253571689128876
# #################
# # EPOCH 2520
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2931802272796631
# AVERAGE VAL LOSS: 0.3029199242591858
# #################
# # EPOCH 2521
# #FOLD 3
# #################
# ...
# AVERAGE TRAIN LOSS: 0.24577102065086365
# AVERAGE VAL LOSS: 0.3272646963596344
# #################
# # EPOCH 2882
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29106324911117554
# AVERAGE VAL LOSS: 0.30539825558662415
# #################
# # EPOCH 2883
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24576207995414734
# AVERAGE VAL LOSS: 0.3272764980792999
# #################
# # EPOCH 2884
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29104742407798767
# AVERAGE VAL LOSS: 0.30541661381721497
# #################
# # EPOCH 2885
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24575388431549072
# AVERAGE VAL LOSS: 0.3272882103919983
# #################
# # EPOCH 2886
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2910314202308655
# AVERAGE VAL LOSS: 0.3054351508617401
# #################
# # EPOCH 2887
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24574501812458038
# AVERAGE VAL LOSS: 0.327300101518631
# #################
# # EPOCH 2888
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29101547598838806
# AVERAGE VAL LOSS: 0.3054535388946533
# #################
# # EPOCH 2889
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24573643505573273
# AVERAGE VAL LOSS: 0.3273119032382965
# #################
# # EPOCH 2890
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29099899530410767
# AVERAGE VAL LOSS: 0.30547234416007996
# #################
# # EPOCH 2891
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2457280158996582
# AVERAGE VAL LOSS: 0.3273239731788635
# #################
# # EPOCH 2892
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29098302125930786
# AVERAGE VAL LOSS: 0.3054909110069275
# #################
# # EPOCH 2893
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24571935832500458
# AVERAGE VAL LOSS: 0.3273363709449768
# #################
# # EPOCH 2894
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.290967732667923
# AVERAGE VAL LOSS: 0.3055097460746765
# #################
# # EPOCH 2895
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2457105815410614
# AVERAGE VAL LOSS: 0.3273483216762543
# #################
# # EPOCH 2896
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2909519076347351
# AVERAGE VAL LOSS: 0.3055284321308136
# #################
# # EPOCH 2897
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24570214748382568
# AVERAGE VAL LOSS: 0.3273606300354004
# #################
# # EPOCH 2898
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2909359335899353
# AVERAGE VAL LOSS: 0.30554714798927307
# #################
# # EPOCH 2899
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24569347500801086
# AVERAGE VAL LOSS: 0.3273729681968689
# #################
# # EPOCH 2900
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2909197509288788
# AVERAGE VAL LOSS: 0.3055657744407654
# #################
# # EPOCH 2901
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2456849366426468
# AVERAGE VAL LOSS: 0.3273847997188568
# #################
# # EPOCH 2902
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.290903240442276
# AVERAGE VAL LOSS: 0.30558472871780396
# #################
# # EPOCH 2903
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24567683041095734
# AVERAGE VAL LOSS: 0.3273966908454895
# #################
# # EPOCH 2904
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29088690876960754
# AVERAGE VAL LOSS: 0.30560383200645447
# #################
# # EPOCH 2905
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2456684410572052
# AVERAGE VAL LOSS: 0.32740887999534607
# #################
# # EPOCH 2906
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2908710241317749
# AVERAGE VAL LOSS: 0.3056229054927826
# #################
# # EPOCH 2907
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24566006660461426
# AVERAGE VAL LOSS: 0.3274214267730713
# #################
# # EPOCH 2908
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2908555567264557
# AVERAGE VAL LOSS: 0.30564194917678833
# #################
# # EPOCH 2909
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24565136432647705
# AVERAGE VAL LOSS: 0.3274339735507965
# #################
# # EPOCH 2910
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2908397316932678
# AVERAGE VAL LOSS: 0.3056609332561493
# #################
# # EPOCH 2911
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24564294517040253
# AVERAGE VAL LOSS: 0.32744675874710083
# #################
# # EPOCH 2912
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2908235490322113
# AVERAGE VAL LOSS: 0.3056803047657013
# #################
# # EPOCH 2913
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.245634526014328
# AVERAGE VAL LOSS: 0.3274590075016022
# #################
# # EPOCH 2914
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2908073365688324
# AVERAGE VAL LOSS: 0.3056991994380951
# #################
# # EPOCH 2915
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24562621116638184
# AVERAGE VAL LOSS: 0.32747122645378113
# #################
# # EPOCH 2916
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29079118371009827
# AVERAGE VAL LOSS: 0.30571869015693665
# #################
# # EPOCH 2917
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2456178367137909
# AVERAGE VAL LOSS: 0.32748401165008545
# #################
# # EPOCH 2918
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29077568650245667
# AVERAGE VAL LOSS: 0.30573800206184387
# #################
# # EPOCH 2919
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24560940265655518
# AVERAGE VAL LOSS: 0.3274966776371002
# #################
# # EPOCH 2920
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2907598316669464
# AVERAGE VAL LOSS: 0.3057572543621063
# #################
# # EPOCH 2921
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24560098350048065
# AVERAGE VAL LOSS: 0.3275095820426941
# #################
# # EPOCH 2922
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2907438576221466
# AVERAGE VAL LOSS: 0.3057766258716583
# #################
# # EPOCH 2923
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24559256434440613
# AVERAGE VAL LOSS: 0.32752203941345215
# #################
# # EPOCH 2924
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2907274663448334
# AVERAGE VAL LOSS: 0.30579617619514465
# #################
# # EPOCH 2925
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24558432400226593
# AVERAGE VAL LOSS: 0.32753506302833557
# #################
# # EPOCH 2926
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2907114624977112
# AVERAGE VAL LOSS: 0.30581602454185486
# #################
# # EPOCH 2927
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455763816833496
# AVERAGE VAL LOSS: 0.3275478482246399
# #################
# # EPOCH 2928
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29069557785987854
# AVERAGE VAL LOSS: 0.3058356046676636
# #################
# # EPOCH 2929
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455682009458542
# AVERAGE VAL LOSS: 0.32756078243255615
# #################
# # EPOCH 2930
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2906797528266907
# AVERAGE VAL LOSS: 0.30585524439811707
# #################
# # EPOCH 2931
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24555936455726624
# AVERAGE VAL LOSS: 0.32757407426834106
# #################
# # EPOCH 2932
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2906647324562073
# AVERAGE VAL LOSS: 0.30587491393089294
# #################
# # EPOCH 2933
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455509603023529
# AVERAGE VAL LOSS: 0.3275873064994812
# #################
# # EPOCH 2934
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29064828157424927
# AVERAGE VAL LOSS: 0.3058945834636688
# #################
# # EPOCH 2935
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455429583787918
# AVERAGE VAL LOSS: 0.32760027050971985
# #################
# # EPOCH 2936
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2906326651573181
# AVERAGE VAL LOSS: 0.3059144616127014
# #################
# # EPOCH 2937
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455345094203949
# AVERAGE VAL LOSS: 0.32761350274086
# #################
# # EPOCH 2938
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29061686992645264
# AVERAGE VAL LOSS: 0.3059343099594116
# #################
# # EPOCH 2939
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455265074968338
# AVERAGE VAL LOSS: 0.32762616872787476
# #################
# # EPOCH 2940
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29060035943984985
# AVERAGE VAL LOSS: 0.3059542179107666
# #################
# # EPOCH 2941
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24551813304424286
# AVERAGE VAL LOSS: 0.3276393711566925
# #################
# # EPOCH 2942
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29058387875556946
# AVERAGE VAL LOSS: 0.3059745132923126
# #################
# # EPOCH 2943
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2455102503299713
# AVERAGE VAL LOSS: 0.32765257358551025
# #################
# # EPOCH 2944
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29056763648986816
# AVERAGE VAL LOSS: 0.30599451065063477
# #################
# # EPOCH 2945
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24550242722034454
# AVERAGE VAL LOSS: 0.32766562700271606
# #################
# # EPOCH 2946
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29055139422416687
# AVERAGE VAL LOSS: 0.30601468682289124
# #################
# # EPOCH 2947
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2454942762851715
# AVERAGE VAL LOSS: 0.3276791572570801
# #################
# # EPOCH 2948
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.290535569190979
# AVERAGE VAL LOSS: 0.3060346841812134
# #################
# # EPOCH 2949
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24548597633838654
# AVERAGE VAL LOSS: 0.3276922106742859
# #################
# # EPOCH 2950
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2905192971229553
# AVERAGE VAL LOSS: 0.306054949760437
# #################
# # EPOCH 2951
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24547791481018066
# AVERAGE VAL LOSS: 0.3277055025100708
# #################
# # EPOCH 2952
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29050302505493164
# AVERAGE VAL LOSS: 0.3060752749443054
# #################
# # EPOCH 2953
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24547000229358673
# AVERAGE VAL LOSS: 0.3277190923690796
# #################
# # EPOCH 2954
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29048651456832886
# AVERAGE VAL LOSS: 0.30609551072120667
# #################
# # EPOCH 2955
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24546179175376892
# AVERAGE VAL LOSS: 0.3277318775653839
# #################
# # EPOCH 2956
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29046961665153503
# AVERAGE VAL LOSS: 0.3061159551143646
# #################
# # EPOCH 2957
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24545426666736603
# AVERAGE VAL LOSS: 0.3277449309825897
# #################
# # EPOCH 2958
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2904529869556427
# AVERAGE VAL LOSS: 0.30613628029823303
# #################
# # EPOCH 2959
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24544623494148254
# AVERAGE VAL LOSS: 0.3277585804462433
# #################
# # EPOCH 2960
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2904370129108429
# AVERAGE VAL LOSS: 0.3061567544937134
# #################
# # EPOCH 2961
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2454380989074707
# AVERAGE VAL LOSS: 0.32777202129364014
# #################
# # EPOCH 2962
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2904210686683655
# AVERAGE VAL LOSS: 0.3061773180961609
# #################
# # EPOCH 2963
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24543006718158722
# AVERAGE VAL LOSS: 0.327785849571228
# #################
# # EPOCH 2964
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29040488600730896
# AVERAGE VAL LOSS: 0.3061978220939636
# #################
# # EPOCH 2965
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2454218864440918
# AVERAGE VAL LOSS: 0.3277997672557831
# #################
# # EPOCH 2966
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2903887927532196
# AVERAGE VAL LOSS: 0.3062181770801544
# #################
# # EPOCH 2967
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24541373550891876
# AVERAGE VAL LOSS: 0.3278133273124695
# #################
# # EPOCH 2968
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2903722822666168
# AVERAGE VAL LOSS: 0.30623921751976013
# #################
# # EPOCH 2969
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24540600180625916
# AVERAGE VAL LOSS: 0.3278266191482544
# #################
# # EPOCH 2970
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29035571217536926
# AVERAGE VAL LOSS: 0.3062599301338196
# #################
# # EPOCH 2971
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24539828300476074
# AVERAGE VAL LOSS: 0.3278403580188751
# #################
# # EPOCH 2972
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29033946990966797
# AVERAGE VAL LOSS: 0.30628079175949097
# #################
# # EPOCH 2973
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24539010226726532
# AVERAGE VAL LOSS: 0.32785436511039734
# #################
# # EPOCH 2974
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29032325744628906
# AVERAGE VAL LOSS: 0.3063015341758728
# #################
# # EPOCH 2975
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24538227915763855
# AVERAGE VAL LOSS: 0.32786837220191956
# #################
# # EPOCH 2976
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29030734300613403
# AVERAGE VAL LOSS: 0.3063225746154785
# #################
# # EPOCH 2977
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24537432193756104
# AVERAGE VAL LOSS: 0.32788270711898804
# #################
# # EPOCH 2978
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29029184579849243
# AVERAGE VAL LOSS: 0.3063434362411499
# #################
# # EPOCH 2979
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24536637961864471
# AVERAGE VAL LOSS: 0.3278971016407013
# #################
# # EPOCH 2980
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29027611017227173
# AVERAGE VAL LOSS: 0.3063647150993347
# #################
# # EPOCH 2981
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2453583925962448
# AVERAGE VAL LOSS: 0.32791122794151306
# #################
# # EPOCH 2982
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29025986790657043
# AVERAGE VAL LOSS: 0.30638572573661804
# #################
# # EPOCH 2983
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24535059928894043
# AVERAGE VAL LOSS: 0.32792508602142334
# #################
# # EPOCH 2984
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2902430593967438
# AVERAGE VAL LOSS: 0.306406706571579
# #################
# # EPOCH 2985
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2453426867723465
# AVERAGE VAL LOSS: 0.3279392123222351
# #################
# # EPOCH 2986
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2902267277240753
# AVERAGE VAL LOSS: 0.306427925825119
# #################
# # EPOCH 2987
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24533505737781525
# AVERAGE VAL LOSS: 0.32795295119285583
# #################
# # EPOCH 2988
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2902100086212158
# AVERAGE VAL LOSS: 0.306449294090271
# #################
# # EPOCH 2989
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24532727897167206
# AVERAGE VAL LOSS: 0.3279668092727661
# #################
# # EPOCH 2990
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29019346833229065
# AVERAGE VAL LOSS: 0.3064703047275543
# #################
# # EPOCH 2991
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2453194558620453
# AVERAGE VAL LOSS: 0.3279809057712555
# #################
# # EPOCH 2992
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2901766896247864
# AVERAGE VAL LOSS: 0.3064916133880615
# #################
# # EPOCH 2993
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2453116923570633
# AVERAGE VAL LOSS: 0.32799527049064636
# #################
# # EPOCH 2994
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29016050696372986
# AVERAGE VAL LOSS: 0.3065131902694702
# #################
# # EPOCH 2995
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.2453041970729828
# AVERAGE VAL LOSS: 0.32800981402397156
# #################
# # EPOCH 2996
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.290144145488739
# AVERAGE VAL LOSS: 0.30653467774391174
# #################
# # EPOCH 2997
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24529652297496796
# AVERAGE VAL LOSS: 0.328023761510849
# #################
# # EPOCH 2998
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.29012781381607056
# AVERAGE VAL LOSS: 0.30655619502067566
# #################
# # EPOCH 2999
# #FOLD 3
# #################
# AVERAGE TRAIN LOSS: 0.24528911709785461
# AVERAGE VAL LOSS: 0.3280385136604309

# %%
print(Models_train_loss)
# Out:
# [0.37044778, 0.37973607, 0.14336367, 0.17349274]

# %%
print(Models_val_loss)
# Out:
# [0.39823258, 0.4255147, 0.3561332, 0.37197986]

# %%
net.eval() # Evaluation mode (e.g. disable dropout)
#load the weights of the network i
net = Net(Ni, 64, 128, No) 
net_state_dict = torch.load('/content/net_parametersFold 3 Space (64, 128, 0.01)')
net.load_state_dict(net_state_dict)
net=net.to(device)
all_inputs = []
all_outputs = []
all_labels = []
with torch.no_grad(): # Disable gradient tracking
    for sample_batched in test_loader:
      # Move data to device
      x_batch = sample_batched[0].to(device)
      label_batch = sample_batched[1].to(device)
      # Forward pass
      out = net(x_batch)
      # Save outputs and labels
      all_inputs.append(x_batch)
      all_outputs.append(out)
      all_labels.append(label_batch)
# Concatenate all the outputs and labels in a single tensor
all_inputs  = torch.cat(all_inputs)
all_outputs = torch.cat(all_outputs)
all_labels  = torch.cat(all_labels)
  
test_loss = loss_fn(all_outputs, all_labels)
# Out:
# Network initialized

# %% [markdown]
# ### **Classification Task**

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split
from torchvision import transforms
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.model_selection import KFold

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
#Initializing a seed for the random varibles
torch.manual_seed(0)

# %%
train_dataset = torchvision.datasets.MNIST('classifier_data', train=True, download=True)
test_dataset  = torchvision.datasets.MNIST('classifier_data', train=False, download=True)
print(len(train_dataset))
print(len(test_dataset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to classifier_data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting classifier_data/MNIST/raw/train-images-idx3-ubyte.gz to classifier_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to classifier_data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting classifier_data/MNIST/raw/train-labels-idx1-ubyte.gz to classifier_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to classifier_data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting classifier_data/MNIST/raw/t10k-images-idx3-ubyte.gz to classifier_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to classifier_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting classifier_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to classifier_data/MNIST/raw
#
# 60000
# 10000
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(train_dataset[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(train_dataset[i][1]))
  plt.xticks([])
  plt.yticks([])
fig

# %% [markdown]
# Definition of the network

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 64, kernel_size=5)
        self.conv2 = nn.Conv2d(64,64, kernel_size=5)
        self.conv3 = nn.Conv2d(64,128, kernel_size=5)
        self.fc1 = nn.Linear(3*3*128,256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv3(x),2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = x.view(-1,3*3*128 )
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# Laod the dataset

# %%
# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Training device: {device}")
# Out:
# Training device: cuda

# %%
x_train=[]
y_train=[]

trainset=[]
testset=[]

for sample in train_dataset:
     x_train.append(np.array(sample[0]))
     y_train.append(np.array(sample[1]))
     trainset.append([torch.from_numpy(np.array(sample[0])),torch.from_numpy(np.array(sample[1])).long()])
for samplet in test_dataset:
     testset.append([torch.from_numpy(np.array(samplet[0])),torch.from_numpy(np.array(samplet[1])).long()])

dataset_train=trainset
dataset_test=testset
print("x_train =",trainset[0][0].shape)
dataloader=DataLoader(dataset=dataset_train,
                         batch_size=64,
                         shuffle=True,
                         )
dataloader_test=DataLoader(dataset=dataset_test,
                         batch_size=64,
                         shuffle=True,
                         )
# Out:
# x_train = torch.Size([28, 28])

# %% [markdown]
# Training the network + Cross validation

# %%
from sklearn.model_selection import KFold
list_accuracy=[]
val_accuracy=0
kfold =KFold(n_splits=10)
for fold, (train_index, val_index) in enumerate(kfold.split(x_train, y_train)):  
    cnn = CNN()
    cnn.to(device) 
    optimizer = torch.optim.Adam(cnn.parameters(),lr=0.001, betas=(0.9,0.999))
    criterion = nn.CrossEntropyLoss()
    #prepare train and validation data
    x_train_fold =torch.from_numpy(np.array(x_train)[train_index]) 
    y_train_fold =torch.from_numpy(np.array(y_train)[train_index])
    x_val_fold = torch.from_numpy(np.array(x_train)[val_index])
    y_val_fold =torch.from_numpy(np.array(y_train)[val_index])
    
    trainfold_dataset=TensorDataset(x_train_fold,y_train_fold)
    valfold_dataset=TensorDataset(x_val_fold,y_val_fold)
    dataloader_trainfold=DataLoader(dataset=trainfold_dataset,
                         batch_size=64,
                         shuffle=True,
                         )
    dataloader_valfold=DataLoader(dataset=valfold_dataset,
                         batch_size=64,
                         shuffle=True,
                         ) 
    #train mode
    cnn.train()
    epochs = 10
    train_loss_log=[]
    val_loss_log=[]
    for e in range(epochs):
        running_loss = 0
        correct=0
        train_loss=[]
        val_loss= []
        cnn.train()
        for images, labels in dataloader_trainfold:
            images = images.view(-1,1,28,28).float().to(device)
            labels=labels.to(device)
            # Training pass
            optimizer.zero_grad()
            output = cnn(images)
            loss = criterion(output, labels)
            #This is where the model learns by backpropagating
            loss.backward()
            #And optimizes its weights here
            optimizer.step()
            running_loss += loss.item()
            # Save train loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            train_loss.append(loss_batch)
        # Save average train loss
        train_loss = np.mean(train_loss)
        train_loss_log.append(train_loss)
        print("Epoch {}  - Average Training loss: {}".format(e, train_loss))
        print('-------------------')
        ### VALIDATION
        cnn.eval() # Evaluation mode (e.g. disable dropout)
        with torch.no_grad(): # Disable gradient tracking
            for images, labels in dataloader_valfold:
               images = images.view(-1,1,28,28).float().to(device)
               labels=labels.to(device)
               # Forward pass
               out = cnn(images)
               #acc
               predicted = torch.max(out,1)[1]
               correct += (predicted == labels).sum()
               # Compute loss
               loss = criterion(out, labels)
               # Save val loss for this batch
               loss_batch = loss.detach().cpu().numpy()
               val_loss.append(loss_batch)
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_accuracy+=float(correct) / (len(dataloader_valfold)*64)
        print("val accuracy:{:.3f}% ".format( float(correct) / (len(dataloader_valfold)*64)))
        val_loss_log.append(val_loss)
    print(val_accuracy/epochs)
    list_accuracy.append(val_accuracy/epochs)
    val_accuracy=0
    print("Train and validation loss figure")
    plt.figure(figsize=(12,6))
    plt.semilogy(train_loss_log, label='Train loss')
    plt.semilogy(val_loss_log, label='Validation loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid()
    plt.legend()
    plt.show()
    Path="/content/ClassificationParametersfold{}.pth".format(fold)
    torch.save(cnn.state_dict(), Path)
# Out:
# Epoch 0  - Average Training loss: 0.5701873302459717
# -------------------
# AVERAGE VAL LOSS: 0.08142513036727905
# val accuracy:0.974%
# Epoch 1  - Average Training loss: 0.17899465560913086
# -------------------
# AVERAGE VAL LOSS: 0.07220954447984695
# val accuracy:0.978%
# Epoch 2  - Average Training loss: 0.15731334686279297
# -------------------
# AVERAGE VAL LOSS: 0.06513284146785736
# val accuracy:0.978%
# Epoch 3  - Average Training loss: 0.15347324311733246
# -------------------
# AVERAGE VAL LOSS: 0.05229131132364273
# val accuracy:0.982%
# Epoch 4  - Average Training loss: 0.1581135243177414
# -------------------
# AVERAGE VAL LOSS: 0.06116064637899399
# val accuracy:0.979%
# Epoch 5  - Average Training loss: 0.14589884877204895
# -------------------
# AVERAGE VAL LOSS: 0.054326143115758896
# val accuracy:0.983%
# Epoch 6  - Average Training loss: 0.1439179629087448
# -------------------
# AVERAGE VAL LOSS: 0.05355583503842354
# val accuracy:0.982%
# Epoch 7  - Average Training loss: 0.15200215578079224
# -------------------
# AVERAGE VAL LOSS: 0.04814564809203148
# val accuracy:0.983%
# Epoch 8  - Average Training loss: 0.1524544358253479
# -------------------
# AVERAGE VAL LOSS: 0.04861515015363693
# val accuracy:0.983%
# Epoch 9  - Average Training loss: 0.14712457358837128
# -------------------
# AVERAGE VAL LOSS: 0.04779181629419327
# val accuracy:0.986%
# 0.9808011968085107
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.5423018336296082
# -------------------
# AVERAGE VAL LOSS: 0.08585590124130249
# val accuracy:0.971%
# Epoch 1  - Average Training loss: 0.17369350790977478
# -------------------
# AVERAGE VAL LOSS: 0.07104383409023285
# val accuracy:0.979%
# Epoch 2  - Average Training loss: 0.15177731215953827
# -------------------
# AVERAGE VAL LOSS: 0.05893729254603386
# val accuracy:0.980%
# Epoch 3  - Average Training loss: 0.14496183395385742
# -------------------
# AVERAGE VAL LOSS: 0.05326010286808014
# val accuracy:0.984%
# Epoch 4  - Average Training loss: 0.13665452599525452
# -------------------
# AVERAGE VAL LOSS: 0.058946285396814346
# val accuracy:0.979%
# Epoch 5  - Average Training loss: 0.14565794169902802
# -------------------
# AVERAGE VAL LOSS: 0.053387757390737534
# val accuracy:0.983%
# Epoch 6  - Average Training loss: 0.14887219667434692
# -------------------
# AVERAGE VAL LOSS: 0.053319793194532394
# val accuracy:0.982%
# Epoch 7  - Average Training loss: 0.14721757173538208
# -------------------
# AVERAGE VAL LOSS: 0.051710084080696106
# val accuracy:0.984%
# Epoch 8  - Average Training loss: 0.14821907877922058
# -------------------
# AVERAGE VAL LOSS: 0.04991692304611206
# val accuracy:0.984%
# Epoch 9  - Average Training loss: 0.15517079830169678
# -------------------
# AVERAGE VAL LOSS: 0.04889247938990593
# val accuracy:0.985%
# 0.9811336436170212
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.5874301791191101
# -------------------
# AVERAGE VAL LOSS: 0.08375374972820282
# val accuracy:0.974%
# Epoch 1  - Average Training loss: 0.1886872947216034
# -------------------
# AVERAGE VAL LOSS: 0.05581697076559067
# val accuracy:0.980%
# Epoch 2  - Average Training loss: 0.16408249735832214
# -------------------
# AVERAGE VAL LOSS: 0.056116119027137756
# val accuracy:0.981%
# Epoch 3  - Average Training loss: 0.15706320106983185
# -------------------
# AVERAGE VAL LOSS: 0.04522905871272087
# val accuracy:0.983%
# Epoch 4  - Average Training loss: 0.15598370134830475
# -------------------
# AVERAGE VAL LOSS: 0.0438581258058548
# val accuracy:0.985%
# Epoch 5  - Average Training loss: 0.15159565210342407
# -------------------
# AVERAGE VAL LOSS: 0.044025909155607224
# val accuracy:0.986%
# Epoch 6  - Average Training loss: 0.15406274795532227
# -------------------
# AVERAGE VAL LOSS: 0.055091749876737595
# val accuracy:0.982%
# Epoch 7  - Average Training loss: 0.15149721503257751
# -------------------
# AVERAGE VAL LOSS: 0.04073401540517807
# val accuracy:0.987%
# Epoch 8  - Average Training loss: 0.15117429196834564
# -------------------
# AVERAGE VAL LOSS: 0.04158204048871994
# val accuracy:0.986%
# Epoch 9  - Average Training loss: 0.15141277015209198
# -------------------
# AVERAGE VAL LOSS: 0.04225172474980354
# val accuracy:0.987%
# 0.9829454787234042
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.6832732558250427
# -------------------
# AVERAGE VAL LOSS: 0.08334363251924515
# val accuracy:0.974%
# Epoch 1  - Average Training loss: 0.2083035558462143
# -------------------
# AVERAGE VAL LOSS: 0.06884041428565979
# val accuracy:0.978%
# Epoch 2  - Average Training loss: 0.1728644222021103
# -------------------
# AVERAGE VAL LOSS: 0.06330583989620209
# val accuracy:0.979%
# Epoch 3  - Average Training loss: 0.15638968348503113
# -------------------
# AVERAGE VAL LOSS: 0.0544734001159668
# val accuracy:0.981%
# Epoch 4  - Average Training loss: 0.162999227643013
# -------------------
# AVERAGE VAL LOSS: 0.05181226506829262
# val accuracy:0.982%
# Epoch 5  - Average Training loss: 0.15885676443576813
# -------------------
# AVERAGE VAL LOSS: 0.05497594177722931
# val accuracy:0.981%
# Epoch 6  - Average Training loss: 0.15452615916728973
# -------------------
# AVERAGE VAL LOSS: 0.046207454055547714
# val accuracy:0.984%
# Epoch 7  - Average Training loss: 0.16090501844882965
# -------------------
# AVERAGE VAL LOSS: 0.04988091439008713
# val accuracy:0.984%
# Epoch 8  - Average Training loss: 0.16130101680755615
# -------------------
# AVERAGE VAL LOSS: 0.0641777440905571
# val accuracy:0.978%
# Epoch 9  - Average Training loss: 0.1563357561826706
# -------------------
# AVERAGE VAL LOSS: 0.04991066828370094
# val accuracy:0.983%
# 0.980252659574468
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.7166494131088257
# -------------------
# AVERAGE VAL LOSS: 0.12117214500904083
# val accuracy:0.967%
# Epoch 1  - Average Training loss: 0.21090048551559448
# -------------------
# AVERAGE VAL LOSS: 0.07501933723688126
# val accuracy:0.977%
# Epoch 2  - Average Training loss: 0.15949514508247375
# -------------------
# AVERAGE VAL LOSS: 0.06689195334911346
# val accuracy:0.979%
# Epoch 3  - Average Training loss: 0.15682968497276306
# -------------------
# AVERAGE VAL LOSS: 0.060437243431806564
# val accuracy:0.980%
# Epoch 4  - Average Training loss: 0.15512457489967346
# -------------------
# AVERAGE VAL LOSS: 0.051157429814338684
# val accuracy:0.981%
# Epoch 5  - Average Training loss: 0.152136892080307
# -------------------
# AVERAGE VAL LOSS: 0.05487186834216118
# val accuracy:0.980%
# Epoch 6  - Average Training loss: 0.16019827127456665
# -------------------
# AVERAGE VAL LOSS: 0.06148146092891693
# val accuracy:0.984%
# Epoch 7  - Average Training loss: 0.15127871930599213
# -------------------
# AVERAGE VAL LOSS: 0.04781179875135422
# val accuracy:0.984%
# Epoch 8  - Average Training loss: 0.14756642282009125
# -------------------
# AVERAGE VAL LOSS: 0.05588441342115402
# val accuracy:0.983%
# Epoch 9  - Average Training loss: 0.15985551476478577
# -------------------
# AVERAGE VAL LOSS: 0.05033440142869949
# val accuracy:0.984%
# 0.9797539893617021
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.5257514715194702
# -------------------
# AVERAGE VAL LOSS: 0.0980217233300209
# val accuracy:0.969%
# Epoch 1  - Average Training loss: 0.17916516959667206
# -------------------
# AVERAGE VAL LOSS: 0.06351063400506973
# val accuracy:0.978%
# Epoch 2  - Average Training loss: 0.15769922733306885
# -------------------
# AVERAGE VAL LOSS: 0.05846381187438965
# val accuracy:0.982%
# Epoch 3  - Average Training loss: 0.15079155564308167
# -------------------
# AVERAGE VAL LOSS: 0.04932117089629173
# val accuracy:0.982%
# Epoch 4  - Average Training loss: 0.14898192882537842
# -------------------
# AVERAGE VAL LOSS: 0.051985785365104675
# val accuracy:0.983%
# Epoch 5  - Average Training loss: 0.14990508556365967
# -------------------
# AVERAGE VAL LOSS: 0.051333822309970856
# val accuracy:0.983%
# Epoch 6  - Average Training loss: 0.15846580266952515
# -------------------
# AVERAGE VAL LOSS: 0.04812745377421379
# val accuracy:0.985%
# Epoch 7  - Average Training loss: 0.14818279445171356
# -------------------
# AVERAGE VAL LOSS: 0.0480337031185627
# val accuracy:0.983%
# Epoch 8  - Average Training loss: 0.15431638062000275
# -------------------
# AVERAGE VAL LOSS: 0.06543004512786865
# val accuracy:0.980%
# Epoch 9  - Average Training loss: 0.15626008808612823
# -------------------
# AVERAGE VAL LOSS: 0.05389977619051933
# val accuracy:0.981%
# 0.9806349734042554
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.5609887838363647
# -------------------
# AVERAGE VAL LOSS: 0.08043073862791061
# val accuracy:0.976%
# Epoch 1  - Average Training loss: 0.17615914344787598
# -------------------
# AVERAGE VAL LOSS: 0.0626896321773529
# val accuracy:0.980%
# Epoch 2  - Average Training loss: 0.15395599603652954
# -------------------
# AVERAGE VAL LOSS: 0.06067228317260742
# val accuracy:0.979%
# Epoch 3  - Average Training loss: 0.15402360260486603
# -------------------
# AVERAGE VAL LOSS: 0.052125584334135056
# val accuracy:0.982%
# Epoch 4  - Average Training loss: 0.15032346546649933
# -------------------
# AVERAGE VAL LOSS: 0.04962044581770897
# val accuracy:0.983%
# Epoch 5  - Average Training loss: 0.1469491720199585
# -------------------
# AVERAGE VAL LOSS: 0.054586540907621384
# val accuracy:0.981%
# Epoch 6  - Average Training loss: 0.1544540673494339
# -------------------
# AVERAGE VAL LOSS: 0.050911057740449905
# val accuracy:0.983%
# Epoch 7  - Average Training loss: 0.14678293466567993
# -------------------
# AVERAGE VAL LOSS: 0.05526403337717056
# val accuracy:0.983%
# Epoch 8  - Average Training loss: 0.14920072257518768
# -------------------
# AVERAGE VAL LOSS: 0.0662013441324234
# val accuracy:0.983%
# Epoch 9  - Average Training loss: 0.1430075764656067
# -------------------
# AVERAGE VAL LOSS: 0.04809744283556938
# val accuracy:0.984%
# 0.9814827127659577
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.6009576320648193
# -------------------
# AVERAGE VAL LOSS: 0.08595272898674011
# val accuracy:0.970%
# Epoch 1  - Average Training loss: 0.19270722568035126
# -------------------
# AVERAGE VAL LOSS: 0.06573773920536041
# val accuracy:0.978%
# Epoch 2  - Average Training loss: 0.16116994619369507
# -------------------
# AVERAGE VAL LOSS: 0.055010370910167694
# val accuracy:0.981%
# Epoch 3  - Average Training loss: 0.15295885503292084
# -------------------
# AVERAGE VAL LOSS: 0.05421823263168335
# val accuracy:0.980%
# Epoch 4  - Average Training loss: 0.1540989875793457
# -------------------
# AVERAGE VAL LOSS: 0.06230096518993378
# val accuracy:0.978%
# Epoch 5  - Average Training loss: 0.15440574288368225
# -------------------
# AVERAGE VAL LOSS: 0.06885930150747299
# val accuracy:0.979%
# Epoch 6  - Average Training loss: 0.14996309578418732
# -------------------
# AVERAGE VAL LOSS: 0.051613789051771164
# val accuracy:0.981%
# Epoch 7  - Average Training loss: 0.15156136453151703
# -------------------
# AVERAGE VAL LOSS: 0.0639033243060112
# val accuracy:0.980%
# Epoch 8  - Average Training loss: 0.1574660986661911
# -------------------
# AVERAGE VAL LOSS: 0.04995887726545334
# val accuracy:0.983%
# Epoch 9  - Average Training loss: 0.15046092867851257
# -------------------
# AVERAGE VAL LOSS: 0.054210830479860306
# val accuracy:0.982%
# 0.9792719414893616
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.6296294331550598
# -------------------
# AVERAGE VAL LOSS: 0.13256391882896423
# val accuracy:0.960%
# Epoch 1  - Average Training loss: 0.19673188030719757
# -------------------
# AVERAGE VAL LOSS: 0.0830296128988266
# val accuracy:0.977%
# Epoch 2  - Average Training loss: 0.16586311161518097
# -------------------
# AVERAGE VAL LOSS: 0.06536740064620972
# val accuracy:0.979%
# Epoch 3  - Average Training loss: 0.16003920137882233
# -------------------
# AVERAGE VAL LOSS: 0.07339474558830261
# val accuracy:0.975%
# Epoch 4  - Average Training loss: 0.15081335604190826
# -------------------
# AVERAGE VAL LOSS: 0.053602613508701324
# val accuracy:0.986%
# Epoch 5  - Average Training loss: 0.15110428631305695
# -------------------
# AVERAGE VAL LOSS: 0.056712280958890915
# val accuracy:0.982%
# Epoch 6  - Average Training loss: 0.15481361746788025
# -------------------
# AVERAGE VAL LOSS: 0.05355033650994301
# val accuracy:0.983%
# Epoch 7  - Average Training loss: 0.15665189921855927
# -------------------
# AVERAGE VAL LOSS: 0.05435981974005699
# val accuracy:0.983%
# Epoch 8  - Average Training loss: 0.15462081134319305
# -------------------
# AVERAGE VAL LOSS: 0.062177449464797974
# val accuracy:0.981%
# Epoch 9  - Average Training loss: 0.15369462966918945
# -------------------
# AVERAGE VAL LOSS: 0.05014969781041145
# val accuracy:0.984%
# 0.9788231382978724
# Train and validation loss figure
# Epoch 0  - Average Training loss: 0.62123042345047
# -------------------
# AVERAGE VAL LOSS: 0.06518644094467163
# val accuracy:0.978%
# Epoch 1  - Average Training loss: 0.19518807530403137
# -------------------
# AVERAGE VAL LOSS: 0.059165481477975845
# val accuracy:0.981%
# Epoch 2  - Average Training loss: 0.16671453416347504
# -------------------
# AVERAGE VAL LOSS: 0.04743411764502525
# val accuracy:0.985%
# Epoch 3  - Average Training loss: 0.16083624958992004
# -------------------
# AVERAGE VAL LOSS: 0.05041198059916496
# val accuracy:0.983%
# Epoch 4  - Average Training loss: 0.16161002218723297
# -------------------
# AVERAGE VAL LOSS: 0.045394111424684525
# val accuracy:0.984%
# Epoch 5  - Average Training loss: 0.15557453036308289
# -------------------
# AVERAGE VAL LOSS: 0.04657164588570595
# val accuracy:0.986%
# Epoch 6  - Average Training loss: 0.1542506068944931
# -------------------
# AVERAGE VAL LOSS: 0.03773508965969086
# val accuracy:0.986%
# Epoch 7  - Average Training loss: 0.15563364326953888
# -------------------
# AVERAGE VAL LOSS: 0.04304924234747887
# val accuracy:0.985%
# Epoch 8  - Average Training loss: 0.1562355011701584
# -------------------
# AVERAGE VAL LOSS: 0.043513815850019455
# val accuracy:0.985%
# Epoch 9  - Average Training loss: 0.15667088329792023
# -------------------
# AVERAGE VAL LOSS: 0.04679017513990402
# val accuracy:0.986%
# 0.983909574468085
# Train and validation loss figure

# %%
print(list_accuracy)
# Out:
# [0.9808011968085107, 0.9811336436170212, 0.9829454787234042, 0.980252659574468, 0.9797539893617021, 0.9806349734042554, 0.9814827127659577, 0.9792719414893616, 0.9788231382978724, 0.983909574468085]

# %%
for fold in range(10):
  test_loss=[]
  correct = 0
  net=CNN()
  PATH="/content/ClassificationParametersfold{}.pth".format(fold)
  net.load_state_dict(torch.load(PATH))
  net.to(device) 
  net.eval()
  for test_imgs, test_labels in dataloader_test:
        test_imgs = test_imgs.view(-1,1,28,28).float().to(device)
        test_labels=test_labels.to(device)       
        output = net(test_imgs)
        predicted = torch.max(output,1)[1]
        correct += (predicted == test_labels).sum()
        loss = criterion(output, test_labels)
               # Save val loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        test_loss.append(loss_batch)
  test_loss = np.mean(test_loss)

  print("Result for model{}".format(fold))
  print(f"Average test loss: {test_loss}")
  print("Model Accuracy:{:.3f}% ".format( float(correct) / (len(dataloader_test)*64)))
# Out:
# Result for model0
# Average test loss: 0.041622698307037354
# Model Accuracy:0.984%
# Result for model1
# Average test loss: 0.04018806666135788
# Model Accuracy:0.983%
# Result for model2
# Average test loss: 0.03984498232603073
# Model Accuracy:0.984%
# Result for model3
# Average test loss: 0.044787995517253876
# Model Accuracy:0.982%
# Result for model4
# Average test loss: 0.04010253772139549
# Model Accuracy:0.985%
# Result for model5
# Average test loss: 0.038741447031497955
# Model Accuracy:0.984%
# Result for model6
# Average test loss: 0.037113092839717865
# Model Accuracy:0.985%
# Result for model7
# Average test loss: 0.0419965535402298
# Model Accuracy:0.983%
# Result for model8
# Average test loss: 0.03924034163355827
# Model Accuracy:0.983%
# Result for model9
# Average test loss: 0.03375449404120445
# Model Accuracy:0.986%

# %%
cnn=CNN()
PATH="/content/ClassificationParametersfold9.pth"
cnn.load_state_dict(torch.load(PATH))
cnn.to(device) 
#Access network parameters :
# First hidden layer
h1_w = cnn.conv1.weight.data.cpu().numpy()
h1_b = cnn.conv1.bias.data.cpu().numpy()

# second hidden layer
h2_w = cnn.conv2.weight.data.cpu().numpy()
h2_b = cnn.conv2.bias.data.cpu().numpy()

# third hidden layer
h3_w = cnn.conv3.weight.data.cpu().numpy()
h3_b = cnn.conv3.bias.data.cpu().numpy()

# 4 th hidden layer
h4_w = cnn.fc1.weight.data.cpu().numpy()
h4_b = cnn.fc1.bias.data.cpu().numpy()

# 5 th hidden layer
h5_w = cnn.fc2.weight.data.cpu().numpy()
h5_b = cnn.fc2.bias.data.cpu().numpy()


### plot weights histograms :

fig, axs = plt.subplots(5, 1, figsize=(12,8))
axs[0].hist(h1_w.flatten(), 50)
axs[0].set_title('First hidden layer weights')
axs[1].hist(h2_w.flatten(), 50)
axs[1].set_title('Second hidden layer weights')
axs[2].hist(h3_w.flatten(), 50)
axs[2].set_title('First hidden layer weights')
axs[3].hist(h4_w.flatten(), 50)
axs[3].set_title('First hidden layer weights')
axs[4].hist(h5_w.flatten(), 50)
axs[4].set_title('First hidden layer weights')
[ax.grid() for ax in axs]
plt.tight_layout()
plt.show()

# %%
cnn=CNN()
PATH="/content/ClassificationParametersfold9.pth"
cnn.load_state_dict(torch.load(PATH))
cnn.to(device) 
count = 0
for elem in trainset:
  plt.subplot(4,3,count+1)

  image=elem[0]
  true_label=elem[1]
  x=elem[0].view(-1,1,28,28).float().to(device)
  y=elem[1].to(device)
  output = cnn(x)
  predicted_label=torch.max(output,1)[1]
  #fig = plt.figure(figsize=(1,1))
  plt.imshow(image, cmap='gist_gray')
  plt.title("prediction = {}".format(predicted_label.cpu().numpy()[0]))

  count+=1
  if(count==12):
    break

plt.subplots_adjust(hspace=1)

# %%
listt=[]
for test_imgs, test_labels in dataloader_test:
        test_imgs = test_imgs.view(-1,1,28,28).float().to(device)
        test_labels=test_labels.to(device)       
        output = net(test_imgs)
        listt.append(test_imgs)

# %%
test_imgs.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
def get_activation(layer, input, output):
    global activation
    activation = torch.sigmoid(output)

### Register hook  
hook_handle = cnn.fc2.register_forward_hook(get_activation)

### Analyze activations
cnn = cnn.to(device)
cnn.eval()
with torch.no_grad():
    x1 = listt[1]
    y1 = cnn(x1)
    z1 = activation
    x2 = listt[2]
    y2 = cnn(x2)
    z2 = activation
    x3 = listt[3]
    y3 = cnn(x3)
    z3 = activation

### Remove hook
hook_handle.remove()

### Plot activations
fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1[:,1].cpu().numpy(), use_line_collection=True)
axs[0].set_title('Last layer activations for input x1')
axs[1].stem(z2[:,1].cpu().numpy(), use_line_collection=True)
axs[1].set_title('Last layer activations for input x2')
axs[2].stem(z3[:,1].cpu().numpy(), use_line_collection=True)
axs[2].set_title('Last layer activations for input x3')
plt.tight_layout()
plt.show()
